# %% [markdown]
# # Imports & Load Data
# 作業に必要なライブラリをインポートして、 以下のデータを読み込みます。
#
# * stock_price : 株価情報
# * stock_list : 銘柄情報
# * stock_fin : 財務諸表
# * stock_labels : 目的変数

# %%
# shap用にg++とgccをインストールします
! apt-get update
! apt-get install -y --no-install-recommends g++ gcc

# 必要なライブラリをインストールします
! pip install shap==0.37.0 slicer==0.0.3 xgboost==1.3.0.post0
# Out:
# Get:1 http://security.debian.org/debian-security stretch/updates InRelease [53.0 kB]
# Ign:2 http://deb.debian.org/debian stretch InRelease
# Hit:3 http://deb.debian.org/debian stretch-updates InRelease
# Hit:4 http://deb.debian.org/debian stretch Release
# Fetched 53.0 kB in 0s (98.6 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++ is already the newest version (4:6.3.0-4).
# gcc is already the newest version (4:6.3.0-4).
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Requirement already satisfied: shap==0.37.0 in /opt/conda/lib/python3.7/site-packages (0.37.0)
# Requirement already satisfied: slicer==0.0.3 in /opt/conda/lib/python3.7/site-packages (0.0.3)
# Requirement already satisfied: xgboost==1.3.0.post0 in /opt/conda/lib/python3.7/site-packages (1.3.0.post0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (1.2.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (1.16.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (0.24.2)
# Requirement already satisfied: tqdm>4.25.0 in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (4.31.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (0.20.3)
# Requirement already satisfied: numba in /opt/conda/lib/python3.7/site-packages (from shap==0.37.0) (0.43.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from pandas->shap==0.37.0) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.7/site-packages (from pandas->shap==0.37.0) (2018.9)
# Requirement already satisfied: llvmlite>=0.28.0dev0 in /opt/conda/lib/python3.7/site-packages (from numba->shap==0.37.0) (0.28.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->shap==0.37.0) (1.12.0)

# %%
import os
import pickle
import sys
import warnings
from glob import glob

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import shap
import xgboost
from scipy.stats import spearmanr
from sklearn.ensemble import (
    ExtraTreesRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor,
)
from sklearn.metrics import accuracy_score, mean_squared_error
from tqdm.auto import tqdm


# 表示用の設定を変更します
# %matplotlib inline
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
pd.options.display.width = 120

# %%
# python 3.7.3であることを確認します
import sys
print(sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %%
# データセット保存先ディレクトリ（""の中身はご自身の環境に合わせて定義してください。）
dataset_dir="/path/to"

# %%
# 読み込むファイルを定義します。
inputs = {
    "stock_list": f"{dataset_dir}/stock_list.csv.gz",
    "stock_price": f"{dataset_dir}/stock_price.csv.gz",
    "stock_fin": f"{dataset_dir}/stock_fin.csv.gz",
    # 本チュートリアルでは使用しないため、コメントアウトしています。
    # "stock_fin_price": f"{dataset_dir}/stock_fin_price.csv.gz",
    "stock_labels": f"{dataset_dir}/stock_labels.csv.gz",
}

# ファイルを読み込みます
dfs = {}
for k, v in inputs.items():
    print(k)
    dfs[k] = pd.read_csv(v)
# Out:
# stock_list
# stock_price
# stock_fin
# stock_labels

# %% [markdown]
# # 欠損値処理

# %%
# stock_finデータを読み込む
stock_fin = dfs["stock_fin"].copy()

# 日付列をpd.Timestamp型に変換してindexに設定
stock_fin["datetime"] = pd.to_datetime(stock_fin["base_date"])
stock_fin.set_index("datetime", inplace=True)
# 2019年までの値を表示
stock_fin = stock_fin[:"2019"]

# データ数の確認
print(stock_fin.shape)

# データの欠損値数を確認
print(stock_fin.isna().sum())

# 欠損値の数を年別に集計
stock_fin = stock_fin.isna()
stock_fin["year"] = stock_fin.index.year

# データの欠損値をプロット
fig, ax = plt.subplots(figsize=(20, 5))
sns.heatmap(stock_fin.groupby("year").agg("sum"), ax=ax)
# Out:
# (64421, 44)
# base_date                                                         0
# Local Code                                                        0
# Result_FinancialStatement AccountingStandard                    239
# Result_FinancialStatement FiscalPeriodEnd                       239
# Result_FinancialStatement ReportType                            239
# Result_FinancialStatement FiscalYear                            239
# Result_FinancialStatement ModifyDate                            239
# Result_FinancialStatement CompanyType                           239
# Result_FinancialStatement ChangeOfFiscalYearEnd                 239
# Result_FinancialStatement NetSales                              256
# Result_FinancialStatement OperatingIncome                      2072
# Result_FinancialStatement OrdinaryIncome                        308
# Result_FinancialStatement NetIncome                             242
# Result_FinancialStatement TotalAssets                           240
# Result_FinancialStatement NetAssets                             240
# Result_FinancialStatement CashFlowsFromOperatingActivities    50039
# Result_FinancialStatement CashFlowsFromFinancingActivities    50083
# Result_FinancialStatement CashFlowsFromInvestingActivities    50045
# Forecast_FinancialStatement AccountingStandard                 1789
# Forecast_FinancialStatement FiscalPeriodEnd                    1789
# Forecast_FinancialStatement ReportType                         1789
# Forecast_FinancialStatement FiscalYear                         1789
# Forecast_FinancialStatement ModifyDate                         1789
# Forecast_FinancialStatement CompanyType                        1789
# Forecast_FinancialStatement ChangeOfFiscalYearEnd              1789
# Forecast_FinancialStatement NetSales                           2766
# Forecast_FinancialStatement OperatingIncome                    3893
# Forecast_FinancialStatement OrdinaryIncome                     2698
# Forecast_FinancialStatement NetIncome                          2143
# Result_Dividend FiscalPeriodEnd                                4255
# Result_Dividend ReportType                                     4255
# Result_Dividend FiscalYear                                     4255
# Result_Dividend ModifyDate                                     4255
# Result_Dividend RecordDate                                     4255
# Result_Dividend DividendPayableDate                           22625
# Result_Dividend QuarterlyDividendPerShare                      4257
# Result_Dividend AnnualDividendPerShare                        31148
# Forecast_Dividend FiscalPeriodEnd                              4140
# Forecast_Dividend ReportType                                   4140
# Forecast_Dividend FiscalYear                                   4140
# Forecast_Dividend ModifyDate                                   4140
# Forecast_Dividend RecordDate                                  20069
# Forecast_Dividend QuarterlyDividendPerShare                    4243
# Forecast_Dividend AnnualDividendPerShare                      31953
# dtype: int64

# %%
COLUMNS = ['Result_FinancialStatement FiscalYear', 'Result_FinancialStatement NetSales',
       'Result_FinancialStatement OperatingIncome', 'Result_FinancialStatement OrdinaryIncome',
       'Result_FinancialStatement NetIncome', 'Result_FinancialStatement TotalAssets',
       'Result_FinancialStatement NetAssets', 'Result_FinancialStatement CashFlowsFromOperatingActivities',
       'Result_FinancialStatement CashFlowsFromFinancingActivities',
       'Result_FinancialStatement CashFlowsFromInvestingActivities', 'Forecast_FinancialStatement FiscalYear',
       'Forecast_FinancialStatement NetSales', 'Forecast_FinancialStatement OperatingIncome',
       'Forecast_FinancialStatement OrdinaryIncome', 'Forecast_FinancialStatement NetIncome',
       'Result_Dividend FiscalYear', 'Result_Dividend QuarterlyDividendPerShare',
       'Result_Dividend AnnualDividendPerShare', 'Forecast_Dividend FiscalYear',
       'Forecast_Dividend QuarterlyDividendPerShare', 'Forecast_Dividend AnnualDividendPerShare',
       'IssuedShareEquityQuote IssuedShare','Section/Products', '33 Sector(Code)', '17 Sector(Code)']

# %%
section_products = {
    "First Section (Domestic)" : 1,
    "JASDAQ(Standard / Domestic)" :2,
    "Second Section(Domestic)" :3,
    "Mothers (Domestic)" : 4,
    "JASDAQ(Growth/Domestic)" :5
}

# %%
def calculate_glossary_of_financial_analysis(row):
    operating_profit_margin = -999
    ordinary_profit_margin = -999
    net_profit_margin = -999
    total_asset_turnover = -999
    net_sales_growth_rate = -999
    ordinary_income_growth_rate = -999
    operationg_income_growth_rate = -999
    total_assets_growth_rate = -999
    net_assets_growth_rate = -999
    eps = -999
    bps = -999
    roe = -999

    # 売上高営業利益率 売上高営業利益率（％）＝営業利益÷売上高×100
    if row['Result_FinancialStatement NetSales'] != 0:
        operating_profit_margin = \
            row['Result_FinancialStatement OperatingIncome'] / \
            row['Result_FinancialStatement NetSales'] * 100
    # 売上高経常利益率　売上高経常利益率（％）＝経常利益÷売上高×100
    if row['Result_FinancialStatement NetSales'] != 0:
        ordinary_profit_margin = \
            row['Result_FinancialStatement OrdinaryIncome'] / \
            row['Result_FinancialStatement NetSales'] * 100
    # 売上高純履歴率　売上高純利益率（％）＝当期純利益÷売上高×100
    if row['Result_FinancialStatement NetSales'] != 0:
        net_profit_margin = row['Result_FinancialStatement NetIncome'] / \
                            row['Result_FinancialStatement NetSales'] * 100
    # 総資本回転率 総資本回転率（％）＝売上高÷総資本（自己資本＋他人資本）×100
    if row['Result_FinancialStatement NetAssets'] != 0:
        total_asset_turnover = row['Result_FinancialStatement NetSales'] / \
                            row['Result_FinancialStatement NetAssets'] * 100
    # 売上高増加率
    if row['Previous_FinancialStatement NetSales'] != 0:
        net_sales_growth_rate = \
            (row['Result_FinancialStatement NetSales'] -
            row['Previous_FinancialStatement NetSales']) / \
            row['Previous_FinancialStatement NetSales'] * 100
    # 経常利益増加率
    if row['Previous_FinancialStatement OrdinaryIncome'] != 0:
        ordinary_income_growth_rate = \
            (row['Result_FinancialStatement OrdinaryIncome'] -
            row['Previous_FinancialStatement OrdinaryIncome']) / \
            row['Previous_FinancialStatement OrdinaryIncome'] * 100

    # 営業利益増加率
    if row['Previous_FinancialStatement OperatingIncome'] != 0:
        operationg_income_growth_rate = \
            (row['Result_FinancialStatement OperatingIncome'] -
            row['Previous_FinancialStatement OperatingIncome']) / \
            row['Previous_FinancialStatement OperatingIncome'] * 100
    # 総資本増加率
    if row['Previous_FinancialStatement TotalAssets'] != 0:
        total_assets_growth_rate = \
            (row['Result_FinancialStatement TotalAssets'] -
            row['Previous_FinancialStatement TotalAssets']) / \
            row['Previous_FinancialStatement TotalAssets'] * 100
    # 純資本増加率
    if row['Previous_FinancialStatement NetAssets'] != 0:
        net_assets_growth_rate = \
            (row['Result_FinancialStatement NetAssets'] -
            row['Previous_FinancialStatement NetAssets']) / \
            row['Previous_FinancialStatement NetAssets'] * 100
    # 一株当たり当期純利益（EPS）
    if row['IssuedShareEquityQuote IssuedShare'] != 0:
        eps = row['Result_FinancialStatement NetIncome'] / \
            row['IssuedShareEquityQuote IssuedShare']
        # BPS 一株当たり純資産（円） ＝ 純資産 ÷ 発行済株式総数
        bps = row['Result_FinancialStatement NetAssets'] / \
            row['IssuedShareEquityQuote IssuedShare']
        # ROE EPS（一株当たり利益）÷ BPS（一株当たり純資産）× 100
        if bps > 0:
            roe = eps / bps * 100
    return pd.Series(
        [operating_profit_margin, ordinary_profit_margin,
            net_profit_margin, total_asset_turnover,
            net_sales_growth_rate, ordinary_income_growth_rate,
            operationg_income_growth_rate, total_assets_growth_rate,
            net_assets_growth_rate, eps, bps, roe])

# %% [markdown]
# # 特徴量の生成

# %%
TRAIN_END = "2017-12-31"
VAL_START = "2018-02-01"
VAL_END = "2018-12-01"
TEST_START = "2019-01-01"

# %%
def get_features_for_predict(dfs, code):
    """
    Args:
        dfs (dict)  : dict of pd.DataFrame include stock_fin, stock_price
        code (int)  : A local code for a listed company
    Returns:
        feature DataFrame (pd.DataFrame)
    """
    # おおまかな手順の1つ目
    # stock_finデータを読み込み
    stock_fin = dfs["stock_fin"].copy()
    
    stock_list = dfs["stock_list"].copy()
    stock_fin = pd.merge(stock_fin, stock_list, on=["Local Code"] )

    # 特定の銘柄コードのデータに絞る
    fin_data = stock_fin[stock_fin["Local Code"] == code].copy()
    # 日付列をpd.Timestamp型に変換してindexに設定
    fin_data["datetime"] = pd.to_datetime(fin_data["base_date"])
    fin_data.set_index("datetime", inplace=True)
    # fin_dataを選択
    fin_data = fin_data[COLUMNS]
    fin_data = fin_data.join(fin_data[['Result_FinancialStatement NetSales', 'Result_FinancialStatement OperatingIncome', 
                                   'Result_FinancialStatement OrdinaryIncome', 'Result_FinancialStatement NetIncome', 
                                   'Result_FinancialStatement TotalAssets', 'Result_FinancialStatement NetAssets',
                                   'Result_FinancialStatement CashFlowsFromOperatingActivities', 
                                   'Result_FinancialStatement CashFlowsFromFinancingActivities',
                                   'Result_FinancialStatement CashFlowsFromInvestingActivities']].rename(columns =
                                                                                                         {'Result_FinancialStatement NetSales': 'Previous_FinancialStatement NetSales',
                                                                                                          'Result_FinancialStatement OperatingIncome': 'Previous_FinancialStatement OperatingIncome', 
                                                                                                          'Result_FinancialStatement OrdinaryIncome': 'Previous_FinancialStatement OrdinaryIncome', 
                                                                                                          'Result_FinancialStatement NetIncome':'Previous_FinancialStatement NetIncome', 
                                                                                                          'Result_FinancialStatement TotalAssets': 'Previous_FinancialStatement TotalAssets', 
                                                                                                          'Result_FinancialStatement NetAssets':'Previous_FinancialStatement NetAssets',
                                                                                                          'Result_FinancialStatement CashFlowsFromOperatingActivities': 'Previous_FinancialStatement CashFlowsFromOperatingActivities', 
                                                                                                          'Result_FinancialStatement CashFlowsFromFinancingActivities':'Previous_FinancialStatement CashFlowsFromFinancingActivities',
                                                                                                          'Result_FinancialStatement CashFlowsFromInvestingActivities':'Previous_FinancialStatement CashFlowsFromInvestingActivities'}).shift(-1))
    fin_data[['operating_profit_margin', 'ordinary_profit_margin', 'net_profit_margin', 'total_asset_turnover',
         'net_sales_growth_rate', 'ordinary_income_growth_rate', 'operationg_income_growth_rate',
          'total_assets_growth_rate', 'net_assets_growth_rate', 'eps', 'bps', 'roe']] = fin_data.apply(calculate_glossary_of_financial_analysis, axis=1)

    # 欠損値処理
    fin_feats = fin_data.fillna(-999)

    # おおまかな手順の2つ目
    # stock_priceデータを読み込む
    price = dfs["stock_price"].copy()
    # 特定の銘柄コードのデータに絞る
    price_data = price[price["Local Code"] == code].copy()
    # 日付列をpd.Timestamp型に変換してindexに設定
    price_data["datetime"] = pd.to_datetime(price_data["EndOfDayQuote Date"])
    price_data.set_index("datetime", inplace=True)
    # 終値のみに絞る
    feats = price_data[["EndOfDayQuote ExchangeOfficialClose"]].copy()
    # 終値の20営業日リターン
    feats["return_1month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(20)
    # 終値の40営業日リターン
    feats["return_2month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(40)
    # 終値の60営業日リターン
    feats["return_3month"] = feats["EndOfDayQuote ExchangeOfficialClose"].pct_change(60)
    # 終値の20営業日ボラティリティ
    feats["volatility_1month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(20).std()
    )
    # 終値の40営業日ボラティリティ
    feats["volatility_2month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(40).std()
    )
    # 終値の60営業日ボラティリティ
    feats["volatility_3month"] = (
        np.log(feats["EndOfDayQuote ExchangeOfficialClose"]).diff().rolling(60).std()
    )
    # 終値と20営業日の単純移動平均線の乖離
    feats["MA_gap_1month"] = feats["EndOfDayQuote ExchangeOfficialClose"] / (
        feats["EndOfDayQuote ExchangeOfficialClose"].rolling(20).mean()
    )
    # 終値と40営業日の単純移動平均線の乖離
    feats["MA_gap_2month"] = feats["EndOfDayQuote ExchangeOfficialClose"] / (
        feats["EndOfDayQuote ExchangeOfficialClose"].rolling(40).mean()
    )
    # 終値と60営業日の単純移動平均線の乖離
    feats["MA_gap_3month"] = feats["EndOfDayQuote ExchangeOfficialClose"] / (
        feats["EndOfDayQuote ExchangeOfficialClose"].rolling(60).mean()
    )
    
    # EWMA
    ALPHA = 0.25
    feats["EWMA"] = feats["EndOfDayQuote ExchangeOfficialClose"]

    for t in zip(feats.index, feats.index[1:]):
        feats.loc[t[1], "EWMA"] = ALPHA * feats.loc[t[1], "EndOfDayQuote ExchangeOfficialClose"] + (1 - ALPHA) * feats.loc[t[0], "EWMA"]
    
    # EMA 10日
    feats["ema_10"] = feats["EndOfDayQuote ExchangeOfficialClose"].ewm(span=10).mean()
    
    # MACD 
    # EMA12
    feats["ema_12"] = feats["EndOfDayQuote ExchangeOfficialClose"].ewm(span=12).mean()
    # EMA 26
    feats["ema_26"] = feats["EndOfDayQuote ExchangeOfficialClose"].ewm(span=26).mean()
    feats["macd"] = feats["ema_12"] - feats["ema_26"]
    feats["signal"] = feats["macd"].ewm(span=9).mean()
    
    # PBR 株価 ÷ BPS（1株あたり純資産）
    feats["pbr"] = feats["EndOfDayQuote ExchangeOfficialClose"] / fin_data["bps"]
    # PER 株価 ÷ 1株当たり利益（EPS）
    feats["per"] = feats["EndOfDayQuote ExchangeOfficialClose"] / fin_data["eps"]

    # おおまかな手順の3つ目
    # 欠損値処理
    feats = feats.fillna(-999)
    # 元データのカラムを削除
    feats = feats.drop(["EndOfDayQuote ExchangeOfficialClose"], axis=1)

    # 財務データの特徴量とマーケットデータの特徴量のインデックスを合わせる
    feats = feats.loc[feats.index.isin(fin_feats.index)]
    fin_feats = fin_feats.loc[fin_feats.index.isin(feats.index)]

    # データを結合
    feats = pd.concat([feats, fin_feats], axis=1).dropna()

    # 欠損値処理を行います。
    feats = feats.replace([np.inf, -np.inf], -999)
    
    # 市場・商品区分を数値に変換
    feats["Section/Products"] = section_products[feats["Section/Products"][0]]
    # 銘柄コードを設定
    feats["code"] = code

    return feats

# %%
def get_features_and_label(dfs, codes, feature, label):
    """
    Args:
        dfs (dict[pd.DataFrame]): loaded data
        codes  (array) : target codes
        feature (pd.DataFrame): features
        label (str) : label column name
    Returns:
        train_X (pd.DataFrame): training data
        train_y (pd.DataFrame): label for train_X
        val_X (pd.DataFrame): validation data
        val_y (pd.DataFrame): label for val_X
        test_X (pd.DataFrame): test data
        test_y (pd.DataFrame): label for test_X
    """
    # 分割データ用の変数を定義
    trains_X, vals_X, tests_X = [], [], []
    trains_y, vals_y, tests_y = [], [], []

    # 銘柄コード毎に特徴量を作成
    for code in tqdm(codes):
        # 特徴量取得
        feats = feature[feature["code"] == code]

        # stock_labelデータを読み込み
        stock_labels = dfs["stock_labels"].copy()
        # 特定の銘柄コードのデータに絞る
        stock_labels = stock_labels[stock_labels["Local Code"] == code]
        # 日付列をpd.Timestamp型に変換してindexに設定
        stock_labels["datetime"] = pd.to_datetime(stock_labels["base_date"])
        stock_labels.set_index("datetime", inplace=True)

        # 特定の目的変数に絞る
        labels = stock_labels[label]
        # nanを削除
        labels.dropna(inplace=True)

        if feats.shape[0] > 0 and labels.shape[0] > 0:
            # 特徴量と目的変数のインデックスを合わせる
            labels = labels.loc[labels.index.isin(feats.index)]
            feats = feats.loc[feats.index.isin(labels.index)]
            labels.index = feats.index

            # データを分割（ホールドアウト法）
            _train_X = feats[: TRAIN_END].copy()
            _val_X = feats[VAL_START : VAL_END].copy()
            _test_X = feats[TEST_START :].copy()

            _train_y = labels[: TRAIN_END].copy()
            _val_y = labels[VAL_START : VAL_END].copy()
            _test_y = labels[TEST_START :].copy()

            # データを配列に格納 (後ほど結合するため)
            trains_X.append(_train_X)
            vals_X.append(_val_X)
            tests_X.append(_test_X)

            trains_y.append(_train_y)
            vals_y.append(_val_y)
            tests_y.append(_test_y)

    # 銘柄毎に作成した説明変数データを結合します。
    train_X = pd.concat(trains_X)
    val_X = pd.concat(vals_X)
    test_X = pd.concat(tests_X)
    # 銘柄毎に作成した目的変数データを結合します。
    train_y = pd.concat(trains_y)
    val_y = pd.concat(vals_y)
    test_y = pd.concat(tests_y)

    return train_X, train_y, val_X, val_y, test_X, test_y

# %%
# 対象銘柄コードを定義
codes = [9984]
# 対象の目的変数を定義
label = "label_high_20"
# 特徴量を取得
feat = get_features_for_predict(dfs, codes[0])
# 特徴量と目的変数を入力し、分割データを取得
ret = get_features_and_label(dfs, codes, feat, label)
for v in ret:
    print(v.T)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# datetime                                              2016-02-10    2016-04-21    2016-05-10    2016-07-28  \
# return_1month                                      -1.913212e-01  8.908766e-02  8.688554e-02 -7.610193e-02
# return_2month                                      -9.990000e+02  1.441458e-01  2.409844e-02 -1.417147e-01
# return_3month                                      -9.990000e+02  2.555166e-01  1.739812e-01 -1.038744e-01
# volatility_1month                                   4.402584e-02  1.717726e-02  2.271106e-02  3.175834e-02
# volatility_2month                                  -9.990000e+02  1.705030e-02  1.818629e-02  3.062359e-02
# volatility_3month                                  -9.990000e+02  3.428422e-02  3.271347e-02  2.758085e-02
# MA_gap_1month                                       9.107187e-01  1.071322e+00  1.008618e+00  9.588478e-01
# MA_gap_2month                                      -9.990000e+02  1.067462e+00  1.037082e+00  9.375874e-01
# MA_gap_3month                                      -9.990000e+02  1.110128e+00  1.066974e+00  9.219905e-01
# EWMA                                                2.459623e+03  2.970546e+03  2.968909e+03  2.707878e+03
# ema_10                                              2.485936e+03  2.944032e+03  2.974836e+03  2.728377e+03
# ema_12                                              2.498677e+03  2.929518e+03  2.973896e+03  2.740636e+03
# ema_26                                              2.548819e+03  2.867611e+03  2.936036e+03  2.801402e+03
# macd                                               -5.014135e+01  6.190755e+01  3.786054e+01 -6.076538e+01
# signal                                             -3.697210e+01  4.137817e+01  5.548102e+01 -4.794613e+01
# pbr                                                 1.247490e+06  1.649950e+06  1.786191e+06  1.713624e+06
# per                                                 1.121217e+07  1.482939e+07  1.320425e+07  2.206106e+07
# Result_FinancialStatement FiscalYear                2.016000e+03  2.016000e+03  2.016000e+03  2.017000e+03
# Result_FinancialStatement NetSales                  6.810206e+06  6.810206e+06  9.153549e+06  2.126521e+06
# Result_FinancialStatement OperatingIncome           8.753220e+05  8.753220e+05  9.994880e+05  3.192360e+05
# Result_FinancialStatement OrdinaryIncome            9.182140e+05  9.182140e+05  1.005764e+06  3.563610e+05
# Result_FinancialStatement NetIncome                 4.289720e+05  4.289720e+05  4.741720e+05  2.541570e+05
# Result_FinancialStatement TotalAssets               2.149765e+07  2.149765e+07  2.070719e+07  2.062223e+07
# Result_FinancialStatement NetAssets                 3.855507e+06  3.855507e+06  3.505271e+06  3.271996e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02 -9.990000e+02  9.401860e+05 -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02 -9.990000e+02  4.327000e+04 -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -9.990000e+02 -1.651682e+06 -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_Dividend FiscalYear                         -9.990000e+02 -9.990000e+02  2.016000e+03  2.016000e+03
# Result_Dividend QuarterlyDividendPerShare          -9.990000e+02 -9.990000e+02  2.100000e+01  2.100000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02 -9.990000e+02  4.100000e+01  4.100000e+01
# Forecast_Dividend FiscalYear                        2.016000e+03  2.016000e+03  2.017000e+03  2.017000e+03
# Forecast_Dividend QuarterlyDividendPerShare         2.000000e+01  2.100000e+01  2.200000e+01  2.200000e+01
# Forecast_Dividend AnnualDividendPerShare            4.000000e+01  4.100000e+01 -9.990000e+02 -9.990000e+02
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                6.810206e+06  9.153549e+06  2.126521e+06  4.271834e+06
# Previous_FinancialStatement OperatingIncome         8.753220e+05  9.994880e+05  3.192360e+05  6.539440e+05
# Previous_FinancialStatement OrdinaryIncome          9.182140e+05  1.005764e+06  3.563610e+05  6.656250e+05
# Previous_FinancialStatement NetIncome               4.289720e+05  4.741720e+05  2.541570e+05  7.662490e+05
# Previous_FinancialStatement TotalAssets             2.149765e+07  2.070719e+07  2.062223e+07  2.289608e+07
# Previous_FinancialStatement NetAssets               3.855507e+06  3.505271e+06  3.271996e+06  3.126322e+06
# Previous_FinancialStatement CashFlowsFromOperat... -9.990000e+02  9.401860e+05 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc... -9.990000e+02  4.327000e+04 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -9.990000e+02 -1.651682e+06 -9.990000e+02 -9.990000e+02
# operating_profit_margin                             1.285309e+01  1.285309e+01  1.091913e+01  1.501213e+01
# ordinary_profit_margin                              1.348291e+01  1.348291e+01  1.098769e+01  1.675793e+01
# net_profit_margin                                   6.298958e+00  6.298958e+00  5.180198e+00  1.195177e+01
# total_asset_turnover                                1.766358e+02  1.766358e+02  2.611367e+02  6.499155e+01
# net_sales_growth_rate                               0.000000e+00 -2.560038e+01  3.304471e+02 -5.021995e+01
# ordinary_income_growth_rate                         0.000000e+00 -8.704825e+00  1.822318e+02 -4.646220e+01
# operationg_income_growth_rate                       0.000000e+00 -1.242296e+01  2.130875e+02 -5.118298e+01
# total_assets_growth_rate                            0.000000e+00  3.817302e+00  4.119972e-01 -9.931169e+00
# net_assets_growth_rate                              0.000000e+00  9.991695e+00  7.129440e+00  4.659597e+00
# eps                                                 2.052680e-04  2.052680e-04  2.268967e-04  1.216170e-04
# bps                                                 1.844904e-03  1.844904e-03  1.677312e-03  1.565687e-03
# roe                                                 1.112622e+01  1.112622e+01  1.352740e+01  7.767644e+00
# code                                                9.984000e+03  9.984000e+03  9.984000e+03  9.984000e+03
#
# datetime                                              2016-11-07    2017-02-08    2017-05-10    2017-08-07  \
# return_1month                                      -3.968613e-02  2.224838e-02  8.804402e-02  9.961943e-03
# return_2month                                      -7.741374e-02  1.144764e-01  4.466859e-02 -4.780498e-02
# return_3month                                       6.066667e-02  4.418064e-01 -3.892833e-03  4.227793e-02
# volatility_1month                                   1.816612e-02  1.522609e-02  1.157811e-02  1.171816e-02
# volatility_2month                                   1.717361e-02  1.409169e-02  1.290494e-02  1.194563e-02
# volatility_3month                                   1.972693e-02  1.948615e-02  1.331634e-02  1.679778e-02
# MA_gap_1month                                       9.694274e-01  1.012936e+00  1.066627e+00  9.912226e-01
# MA_gap_2month                                       9.660428e-01  1.050702e+00  1.070177e+00  9.902299e-01
# MA_gap_3month                                       9.633156e-01  1.115042e+00  1.051330e+00  1.002253e+00
# EWMA                                                3.216363e+03  4.336250e+03  4.259626e+03  4.485870e+03
# ema_10                                              3.234133e+03  4.329443e+03  4.221973e+03  4.502996e+03
# ema_12                                              3.242589e+03  4.320964e+03  4.200552e+03  4.511513e+03
# ema_26                                              3.268088e+03  4.222146e+03  4.126862e+03  4.530439e+03
# macd                                               -2.549968e+01  9.881878e+01  7.368995e+01 -1.892640e+01
# signal                                             -7.695688e+00  1.197418e+02  3.518196e+01  2.139964e+00
# pbr                                                 2.127033e+06  2.278913e+06  2.033835e+06  2.025501e+06
# per                                                 8.678366e+06  1.058275e+07  6.373583e+06  1.707697e+09
# Result_FinancialStatement FiscalYear                2.017000e+03  2.017000e+03  2.017000e+03  2.018000e+03
# Result_FinancialStatement NetSales                  4.271834e+06  6.581466e+06  8.901004e+06  2.186059e+06
# Result_FinancialStatement OperatingIncome           6.539440e+05  9.496600e+05  1.025999e+06  4.792730e+05
# Result_FinancialStatement OrdinaryIncome            6.656250e+05  9.752570e+05  7.125260e+05  7.756800e+04
# Result_FinancialStatement NetIncome                 7.662490e+05  8.574310e+05  1.426308e+06  5.521000e+03
# Result_FinancialStatement TotalAssets               2.289608e+07  2.486704e+07  2.463421e+07  2.488313e+07
# Result_FinancialStatement NetAssets                 3.126322e+06  3.981711e+06  4.469730e+06  4.654749e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02 -9.990000e+02  1.500728e+06 -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02 -9.990000e+02  2.380746e+06 -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -9.990000e+02 -4.213597e+06 -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_Dividend FiscalYear                          2.017000e+03  2.017000e+03  2.017000e+03  2.017000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02 -9.990000e+02  4.400000e+01  4.400000e+01
# Forecast_Dividend FiscalYear                        2.017000e+03  2.017000e+03  2.018000e+03  2.018000e+03
# Forecast_Dividend QuarterlyDividendPerShare         2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Forecast_Dividend AnnualDividendPerShare            4.400000e+01  4.400000e+01 -9.990000e+02 -9.990000e+02
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                6.581466e+06  8.901004e+06  2.186059e+06  4.411135e+06
# Previous_FinancialStatement OperatingIncome         9.496600e+05  1.025999e+06  4.792730e+05  8.748390e+05
# Previous_FinancialStatement OrdinaryIncome          9.752570e+05  7.125260e+05  7.756800e+04  2.190210e+05
# Previous_FinancialStatement NetIncome               8.574310e+05  1.426308e+06  5.521000e+03  1.026220e+05
# Previous_FinancialStatement TotalAssets             2.486704e+07  2.463421e+07  2.488313e+07  2.797348e+07
# Previous_FinancialStatement NetAssets               3.981711e+06  4.469730e+06  4.654749e+06  5.468373e+06
# Previous_FinancialStatement CashFlowsFromOperat... -9.990000e+02  1.500728e+06 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc... -9.990000e+02  2.380746e+06 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -9.990000e+02 -4.213597e+06 -9.990000e+02 -9.990000e+02
# operating_profit_margin                             1.530827e+01  1.442931e+01  1.152678e+01  2.192407e+01
# ordinary_profit_margin                              1.558172e+01  1.481823e+01  8.005007e+00  3.548303e+00
# net_profit_margin                                   1.793724e+01  1.302796e+01  1.602412e+01  2.525549e-01
# total_asset_turnover                                1.366409e+02  1.652924e+02  1.991396e+02  4.696406e+01
# net_sales_growth_rate                              -3.509297e+01 -2.605928e+01  3.071713e+02 -5.044226e+01
# ordinary_income_growth_rate                        -3.174876e+01  3.687318e+01  8.185824e+02 -6.458422e+01
# operationg_income_growth_rate                      -3.113914e+01 -7.440456e+00  1.140740e+02 -4.521586e+01
# total_assets_growth_rate                           -7.925998e+00  9.451327e-01 -1.000352e+00 -1.104743e+01
# net_assets_growth_rate                             -2.148295e+01 -1.091831e+01 -3.974844e+00 -1.487872e+01
# eps                                                 3.666589e-04  4.102905e-04  6.825047e-04  2.641861e-06
# bps                                                 1.495981e-03  1.905294e-03  2.138817e-03  2.227351e-03
# roe                                                 2.450960e+01  2.153423e+01  3.191038e+01  1.186100e-01
# code                                                9.984000e+03  9.984000e+03  9.984000e+03  9.984000e+03
#
# datetime                                              2017-11-06
# return_1month                                       8.356941e-02
# return_2month                                       1.592260e-01
# return_3month                                       1.126650e-01
# volatility_1month                                   1.838358e-02
# volatility_2month                                   1.601125e-02
# volatility_3month                                   1.444113e-02
# MA_gap_1month                                       9.996080e-01
# MA_gap_2month                                       1.054210e+00
# MA_gap_3month                                       1.079846e+00
# EWMA                                                5.049587e+03
# ema_10                                              5.038808e+03
# ema_12                                              5.025423e+03
# ema_26                                              4.903073e+03
# macd                                                1.223500e+02
# signal                                              1.392616e+02
# pbr                                                 1.900310e+06
# per                                                 1.012610e+08
# Result_FinancialStatement FiscalYear                2.018000e+03
# Result_FinancialStatement NetSales                  4.411135e+06
# Result_FinancialStatement OperatingIncome           8.748390e+05
# Result_FinancialStatement OrdinaryIncome            2.190210e+05
# Result_FinancialStatement NetIncome                 1.026220e+05
# Result_FinancialStatement TotalAssets               2.797348e+07
# Result_FinancialStatement NetAssets                 5.468373e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02
# Result_Dividend FiscalYear                          2.018000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02
# Forecast_Dividend FiscalYear                        2.018000e+03
# Forecast_Dividend QuarterlyDividendPerShare         2.200000e+01
# Forecast_Dividend AnnualDividendPerShare            4.400000e+01
# IssuedShareEquityQuote IssuedShare                  2.089814e+09
# Section/Products                                    1.000000e+00
# 33 Sector(Code)                                     5.250000e+03
# 17 Sector(Code)                                     1.000000e+01
# Previous_FinancialStatement NetSales                6.811274e+06
# Previous_FinancialStatement OperatingIncome         1.148829e+06
# Previous_FinancialStatement OrdinaryIncome          5.638040e+05
# Previous_FinancialStatement NetIncome               1.014944e+06
# Previous_FinancialStatement TotalAssets             2.941272e+07
# Previous_FinancialStatement NetAssets               6.568877e+06
# Previous_FinancialStatement CashFlowsFromOperat... -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc... -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -9.990000e+02
# operating_profit_margin                             1.983251e+01
# ordinary_profit_margin                              4.965185e+00
# net_profit_margin                                   2.326431e+00
# total_asset_turnover                                8.066632e+01
# net_sales_growth_rate                              -3.523774e+01
# ordinary_income_growth_rate                        -6.115299e+01
# operationg_income_growth_rate                      -2.384950e+01
# total_assets_growth_rate                           -4.893240e+00
# net_assets_growth_rate                             -1.675331e+01
# eps                                                 4.910580e-05
# bps                                                 2.616679e-03
# roe                                                 1.876646e+00
# code                                                9.984000e+03
# datetime
# 2016-02-10    0.29763
# 2016-04-21    0.04681
# 2016-05-10    0.07527
# 2016-07-28    0.30675
# 2016-11-07    0.09679
# 2017-02-08    0.03363
# 2017-05-10    0.06322
# 2017-08-07    0.00554
# 2017-11-06    0.01709
# Name: label_high_20, dtype: float64
# datetime                                              2018-02-07    2018-05-09    2018-08-06    2018-11-05
# return_1month                                      -5.596001e-02  1.203510e-01  1.374653e-01 -2.102032e-01
# return_2month                                      -6.940874e-02  7.893497e-03  1.775059e-01 -1.119797e-01
# return_3month                                      -1.333666e-01 -1.530847e-02  1.065103e-01 -1.693257e-01
# volatility_1month                                   1.995841e-02  1.387375e-02  2.234456e-02  4.054193e-02
# volatility_2month                                   1.687287e-02  1.634615e-02  2.083745e-02  3.290983e-02
# volatility_3month                                   1.580369e-02  1.608024e-02  1.943844e-02  2.879765e-02
# MA_gap_1month                                       9.540805e-01  1.044586e+00  1.007283e+00  9.445341e-01
# MA_gap_2month                                       9.530104e-01  1.043655e+00  1.074974e+00  8.712824e-01
# MA_gap_3month                                       9.376535e-01  1.019751e+00  1.101696e+00  8.690109e-01
# EWMA                                                4.406237e+03  4.225049e+03  4.670359e+03  4.372986e+03
# ema_10                                              4.445259e+03  4.198777e+03  4.668784e+03  4.426931e+03
# ema_12                                              4.464104e+03  4.183174e+03  4.661647e+03  4.467873e+03
# ema_26                                              4.532142e+03  4.136273e+03  4.557921e+03  4.703583e+03
# macd                                               -6.803790e+01  4.690086e+01  1.037260e+02 -2.357098e+02
# signal                                             -3.369906e+01  1.603587e+01  1.330114e+02 -2.139218e+02
# pbr                                                 1.381995e+06  1.425020e+06  1.445002e+06  1.244672e+06
# per                                                 8.944487e+06  8.603829e+06  3.142180e+07  1.087938e+07
# Result_FinancialStatement FiscalYear                2.018000e+03  2.018000e+03  2.019000e+03  2.019000e+03
# Result_FinancialStatement NetSales                  6.811274e+06  9.158765e+06  2.272783e+06  4.653853e+06
# Result_FinancialStatement OperatingIncome           1.148829e+06  1.303801e+06  7.149930e+05  1.420716e+06
# Result_FinancialStatement OrdinaryIncome            5.638040e+05  3.846300e+05  5.723040e+05  1.402089e+06
# Result_FinancialStatement NetIncome                 1.014944e+06  1.038977e+06  3.136870e+05  8.401030e+05
# Result_FinancialStatement TotalAssets               2.941272e+07  3.118047e+07  3.226836e+07  3.380756e+07
# Result_FinancialStatement NetAssets                 6.568877e+06  6.273022e+06  6.821174e+06  7.343144e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02  1.088623e+06 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02  4.626421e+06 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -4.484822e+06 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_Dividend FiscalYear                          2.018000e+03  2.018000e+03  2.018000e+03  2.019000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02  4.400000e+01  4.400000e+01 -9.990000e+02
# Forecast_Dividend FiscalYear                        2.018000e+03 -9.990000e+02  2.019000e+03  2.019000e+03
# Forecast_Dividend QuarterlyDividendPerShare         2.200000e+01 -9.990000e+02  2.200000e+01  2.200000e+01
# Forecast_Dividend AnnualDividendPerShare            4.400000e+01 -9.990000e+02 -9.990000e+02  4.400000e+01
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                9.158765e+06  2.272783e+06  4.653853e+06  7.168452e+06
# Previous_FinancialStatement OperatingIncome         1.303801e+06  7.149930e+05  1.420716e+06  1.859007e+06
# Previous_FinancialStatement OrdinaryIncome          3.846300e+05  5.723040e+05  1.402089e+06  1.809834e+06
# Previous_FinancialStatement NetIncome               1.038977e+06  3.136870e+05  8.401030e+05  1.538396e+06
# Previous_FinancialStatement TotalAssets             3.118047e+07  3.226836e+07  3.380756e+07  3.645948e+07
# Previous_FinancialStatement NetAssets               6.273022e+06  6.821174e+06  7.343144e+06  9.286389e+06
# Previous_FinancialStatement CashFlowsFromOperat...  1.088623e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc...  4.626421e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -4.484822e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# operating_profit_margin                             1.686658e+01  1.423555e+01  3.145892e+01  3.052774e+01
# ordinary_profit_margin                              8.277512e+00  4.199584e+00  2.518076e+01  3.012749e+01
# net_profit_margin                                   1.490094e+01  1.134407e+01  1.380189e+01  1.805177e+01
# total_asset_turnover                                1.036901e+02  1.460024e+02  3.331953e+01  6.337685e+01
# net_sales_growth_rate                              -2.563109e+01  3.029758e+02 -5.116341e+01 -3.507869e+01
# ordinary_income_growth_rate                         4.658347e+01 -3.279271e+01 -5.918205e+01 -2.252941e+01
# operationg_income_growth_rate                      -1.188617e+01  8.235158e+01 -4.967376e+01 -2.357662e+01
# total_assets_growth_rate                           -5.669409e+00 -3.371407e+00 -4.552802e+00 -7.273615e+00
# net_assets_growth_rate                              4.716307e+00 -8.036036e+00 -7.108263e+00 -2.092573e+01
# eps                                                 4.856623e-04  4.971623e-04  1.501028e-04  4.019989e-04
# bps                                                 3.143283e-03  3.001713e-03  3.264010e-03  3.513778e-03
# roe                                                 1.545080e+01  1.656262e+01  4.598725e+00  1.144064e+01
# code                                                9.984000e+03  9.984000e+03  9.984000e+03  9.984000e+03
# datetime
# 2018-02-07    0.05767
# 2018-05-09    0.01110
# 2018-08-06    0.12371
# 2018-11-05    0.11810
# Name: label_high_20, dtype: float64
# datetime                                              2019-02-06    2019-05-09    2019-08-07    2019-11-06  \
# return_1month                                       8.878024e-02  5.914718e-02 -4.413740e-03  4.902913e-02
# return_2month                                      -1.097317e-01  1.015737e-01  1.675649e-02 -8.101212e-02
# return_3month                                      -3.258260e-02  3.665405e-01  3.811906e-02 -1.688462e-01
# volatility_1month                                   1.672133e-02  1.514235e-02  2.397602e-02  1.696050e-02
# volatility_2month                                   2.824798e-02  1.593598e-02  2.228841e-02  1.804909e-02
# volatility_3month                                   2.756937e-02  2.729567e-02  2.419688e-02  1.791320e-02
# MA_gap_1month                                       1.052259e+00  1.014114e+00  9.641599e-01  1.033230e+00
# MA_gap_2month                                       1.046151e+00  1.043537e+00  9.861688e-01  9.938260e-01
# MA_gap_3month                                       1.006648e+00  1.073046e+00  9.971634e-01  9.581661e-01
# EWMA                                                4.180759e+03  5.759659e+03  5.388780e+03  4.212239e+03
# ema_10                                              4.146513e+03  5.751040e+03  5.414226e+03  4.198364e+03
# ema_12                                              4.126456e+03  5.741176e+03  5.416650e+03  4.196716e+03
# ema_26                                              4.077843e+03  5.636683e+03  5.365682e+03  4.257246e+03
# macd                                                4.861263e+01  1.044927e+02  5.096812e+01 -6.052971e+01
# signal                                              3.145112e+00  1.235855e+02  9.060111e+01 -9.876220e+01
# pbr                                                 9.521467e+05  1.339594e+06  1.147864e+06  1.047376e+06
# per                                                 5.747548e+06  8.552074e+06  9.665484e+06  2.142601e+07
# Result_FinancialStatement FiscalYear                2.019000e+03  2.019000e+03  2.020000e+03  2.020000e+03
# Result_FinancialStatement NetSales                  7.168452e+06  9.602236e+06  2.336397e+06  4.651724e+06
# Result_FinancialStatement OperatingIncome           1.859007e+06  2.353931e+06  6.888160e+05 -1.555200e+04
# Result_FinancialStatement OrdinaryIncome            1.809834e+06  1.691302e+06  1.682344e+06  1.116897e+06
# Result_FinancialStatement NetIncome                 1.538396e+06  1.411199e+06  1.121719e+06  4.215520e+05
# Result_FinancialStatement TotalAssets               3.645948e+07  3.609648e+07  3.658696e+07  3.684870e+07
# Result_FinancialStatement NetAssets                 9.286389e+06  9.009204e+06  9.445332e+06  8.623626e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02  1.171864e+06 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02  2.202291e+06 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -2.908016e+06 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_Dividend FiscalYear                          2.019000e+03  2.019000e+03  2.019000e+03  2.020000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02  4.400000e+01  4.400000e+01 -9.990000e+02
# Forecast_Dividend FiscalYear                        2.019000e+03  2.020000e+03  2.020000e+03  2.020000e+03
# Forecast_Dividend QuarterlyDividendPerShare         2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Forecast_Dividend AnnualDividendPerShare            4.400000e+01 -9.990000e+02 -9.990000e+02  4.400000e+01
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                9.602236e+06  2.336397e+06  4.651724e+06  7.089804e+06
# Previous_FinancialStatement OperatingIncome         2.353931e+06  6.888160e+05 -1.555200e+04 -1.296400e+04
# Previous_FinancialStatement OrdinaryIncome          1.691302e+06  1.682344e+06  1.116897e+06  1.345378e+06
# Previous_FinancialStatement NetIncome               1.411199e+06  1.121719e+06  4.215520e+05  4.765870e+05
# Previous_FinancialStatement TotalAssets             3.609648e+07  3.658696e+07  3.684870e+07  3.940644e+07
# Previous_FinancialStatement NetAssets               9.009204e+06  9.445332e+06  8.623626e+06  9.191419e+06
# Previous_FinancialStatement CashFlowsFromOperat...  1.171864e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc...  2.202291e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -2.908016e+06 -9.990000e+02 -9.990000e+02 -9.990000e+02
# operating_profit_margin                             2.593317e+01  2.451440e+01  2.948198e+01 -3.343277e-01
# ordinary_profit_margin                              2.524721e+01  1.761363e+01  7.200591e+01  2.401039e+01
# net_profit_margin                                   2.146064e+01  1.469657e+01  4.801063e+01  9.062275e+00
# total_asset_turnover                                7.719310e+01  1.065825e+02  2.473600e+01  5.394163e+01
# net_sales_growth_rate                              -2.534601e+01  3.109848e+02 -4.977352e+01 -3.438854e+01
# ordinary_income_growth_rate                         7.008328e+00  5.324714e-01  5.062660e+01 -1.698266e+01
# operationg_income_growth_rate                      -2.102543e+01  2.417358e+02 -4.529115e+03  1.996297e+01
# total_assets_growth_rate                            1.005641e+00 -1.340601e+00 -7.103100e-01 -6.490655e+00
# net_assets_growth_rate                              3.076687e+00 -4.617392e+00  9.528544e+00 -6.177425e+00
# eps                                                 7.361400e-04  6.752748e-04  5.367553e-04  2.017174e-04
# bps                                                 4.443643e-03  4.311007e-03  4.519699e-03  4.126503e-03
# roe                                                 1.656614e+01  1.566397e+01  1.187591e+01  4.888338e+00
# code                                                9.984000e+03  9.984000e+03  9.984000e+03  9.984000e+03
#
# datetime                                              2020-02-12    2020-04-13    2020-04-30    2020-05-18  \
# return_1month                                       1.390374e-01  1.158342e-01  2.606803e-01  4.547511e-02
# return_2month                                       3.389988e-01 -2.304874e-01 -8.942610e-02  2.591281e-01
# return_3month                                       3.455779e-01 -1.564571e-01  2.409372e-02 -1.624071e-01
# volatility_1month                                   3.441563e-02  8.639982e-02  3.362599e-02  2.807880e-02
# volatility_2month                                   2.717941e-02  6.703024e-02  6.833698e-02  6.368045e-02
# volatility_3month                                   2.312453e-02  5.856385e-02  6.008750e-02  5.734101e-02
# MA_gap_1month                                       1.196816e+00  1.109218e+00  1.066639e+00  1.010287e+00
# MA_gap_2month                                       1.218323e+00  9.579964e-01  1.119096e+00  1.100513e+00
# MA_gap_3month                                       1.260576e+00  9.266409e-01  1.031623e+00  1.043319e+00
# EWMA                                                5.061225e+03  4.120243e+03  4.547565e+03  4.605597e+03
# ema_10                                              4.962775e+03  4.062593e+03  4.508391e+03  4.595510e+03
# ema_12                                              4.922829e+03  4.040147e+03  4.480372e+03  4.583869e+03
# ema_26                                              4.792470e+03  4.092409e+03  4.361642e+03  4.488344e+03
# macd                                                1.303595e+02 -5.226218e+01  1.187305e+02  9.552531e+01
# signal                                              4.646933e+01 -1.614377e+02  8.293155e+01  1.050907e+02
# pbr                                                 1.307581e+06  9.549364e+05  1.053386e+06  1.309798e+06
# per                                                 2.521790e+07  1.841683e+07  2.031551e+07 -1.004292e+07
# Result_FinancialStatement FiscalYear                2.020000e+03  2.020000e+03  2.020000e+03  2.020000e+03
# Result_FinancialStatement NetSales                  7.089804e+06  7.089804e+06  7.089804e+06  6.185093e+06
# Result_FinancialStatement OperatingIncome          -1.296400e+04 -1.296400e+04 -1.296400e+04 -1.364633e+06
# Result_FinancialStatement OrdinaryIncome            1.345378e+06  1.345378e+06  1.345378e+06  3.549200e+04
# Result_FinancialStatement NetIncome                 4.765870e+05  4.765870e+05  4.765870e+05 -9.615760e+05
# Result_FinancialStatement TotalAssets               3.940644e+07  3.940644e+07  3.940644e+07  3.725729e+07
# Result_FinancialStatement NetAssets                 9.191419e+06  9.191419e+06  9.191419e+06  7.372917e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02 -9.990000e+02 -9.990000e+02  1.117879e+06
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02 -9.990000e+02 -9.990000e+02  2.920863e+06
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -9.990000e+02 -9.990000e+02 -4.286921e+06
# Forecast_FinancialStatement FiscalYear             -9.990000e+02  2.020000e+03  2.020000e+03 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02  6.150000e+06  6.150000e+06 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -1.350000e+06 -1.350000e+06 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02  2.500000e+05  2.000000e+04 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -7.500000e+05 -9.000000e+05 -9.990000e+02
# Result_Dividend FiscalYear                          2.020000e+03  2.020000e+03  2.020000e+03  2.020000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# Result_Dividend AnnualDividendPerShare             -9.990000e+02 -9.990000e+02 -9.990000e+02  4.400000e+01
# Forecast_Dividend FiscalYear                        2.020000e+03  2.020000e+03  2.020000e+03 -9.990000e+02
# Forecast_Dividend QuarterlyDividendPerShare         2.200000e+01  2.200000e+01  2.200000e+01 -9.990000e+02
# Forecast_Dividend AnnualDividendPerShare            4.400000e+01  4.400000e+01  4.400000e+01 -9.990000e+02
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                7.089804e+06  7.089804e+06  6.185093e+06  1.450055e+06
# Previous_FinancialStatement OperatingIncome        -1.296400e+04 -1.296400e+04 -1.364633e+06 -9.990000e+02
# Previous_FinancialStatement OrdinaryIncome          1.345378e+06  1.345378e+06  3.549200e+04  8.330470e+05
# Previous_FinancialStatement NetIncome               4.765870e+05  4.765870e+05 -9.615760e+05  1.255712e+06
# Previous_FinancialStatement TotalAssets             3.940644e+07  3.940644e+07  3.725729e+07  3.356335e+07
# Previous_FinancialStatement NetAssets               9.191419e+06  9.191419e+06  7.372917e+06  7.576780e+06
# Previous_FinancialStatement CashFlowsFromOperat... -9.990000e+02 -9.990000e+02  1.117879e+06 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc... -9.990000e+02 -9.990000e+02  2.920863e+06 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -9.990000e+02 -9.990000e+02 -4.286921e+06 -9.990000e+02
# operating_profit_margin                            -1.828541e-01 -1.828541e-01 -1.828541e-01 -2.206326e+01
# ordinary_profit_margin                              1.897624e+01  1.897624e+01  1.897624e+01  5.738313e-01
# net_profit_margin                                   6.722146e+00  6.722146e+00  6.722146e+00 -1.554667e+01
# total_asset_turnover                                7.713503e+01  7.713503e+01  7.713503e+01  8.388936e+01
# net_sales_growth_rate                               0.000000e+00  0.000000e+00  1.462728e+01  3.265420e+02
# ordinary_income_growth_rate                         0.000000e+00  0.000000e+00  3.690651e+03 -9.573950e+01
# operationg_income_growth_rate                      -0.000000e+00 -0.000000e+00 -9.905000e+01 -9.990000e+02
# total_assets_growth_rate                            0.000000e+00  0.000000e+00  5.768388e+00  1.100589e+01
# net_assets_growth_rate                              0.000000e+00  0.000000e+00  2.466462e+01 -2.690628e+00
# eps                                                 2.280523e-04  2.280523e-04  2.280523e-04 -4.601251e-04
# bps                                                 4.398199e-03  4.398199e-03  4.398199e-03  3.528025e-03
# roe                                                 5.185130e+00  5.185130e+00  5.185130e+00 -1.304200e+01
# code                                                9.984000e+03  9.984000e+03  9.984000e+03  9.984000e+03
#
# datetime                                              2020-08-11    2020-10-23    2020-11-09
# return_1month                                       1.112701e-02  1.489293e-01  1.229098e-02
# return_2month                                       2.268081e-01  6.656627e-02  2.476660e-01
# return_3month                                       4.041943e-01  6.576373e-02  1.438953e-01
# volatility_1month                                   2.506267e-02  1.671309e-02  2.384297e-02
# volatility_2month                                   2.546068e-02  2.740215e-02  2.594448e-02
# volatility_3month                                   2.369026e-02  2.694665e-02  2.668409e-02
# MA_gap_1month                                       9.711673e-01  1.026183e+00  1.015520e+00
# MA_gap_2month                                       1.052475e+00  1.073177e+00  1.051756e+00
# MA_gap_3month                                       1.123141e+00  1.079417e+00  1.073711e+00
# EWMA                                                6.563248e+03  7.087225e+03  6.861518e+03
# ema_10                                              6.570358e+03  7.057370e+03  6.869216e+03
# ema_12                                              6.559064e+03  7.030854e+03  6.874400e+03
# ema_26                                              6.350345e+03  6.844455e+03  6.840524e+03
# macd                                                2.087190e+02  1.863984e+02  3.387585e+01
# signal                                              2.788957e+02  1.902143e+02  6.811750e+01
# pbr                                                 1.754480e+06  1.953345e+06  1.757849e+06
# per                                                 1.058627e+07  1.178619e+07  7.860062e+06
# Result_FinancialStatement FiscalYear                2.021000e+03  2.021000e+03  2.021000e+03
# Result_FinancialStatement NetSales                  1.450055e+06  1.450055e+06  2.630531e+06
# Result_FinancialStatement OperatingIncome          -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement OrdinaryIncome            8.330470e+05  8.330470e+05  1.441472e+06
# Result_FinancialStatement NetIncome                 1.255712e+06  1.255712e+06  1.883211e+06
# Result_FinancialStatement TotalAssets               3.356335e+07  3.356335e+07  3.564820e+07
# Result_FinancialStatement NetAssets                 7.576780e+06  7.576780e+06  8.420605e+06
# Result_FinancialStatement CashFlowsFromOperatin... -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromFinancin... -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_FinancialStatement CashFlowsFromInvestin... -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement FiscalYear             -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetSales               -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement OrdinaryIncome         -9.990000e+02 -9.990000e+02 -9.990000e+02
# Forecast_FinancialStatement NetIncome              -9.990000e+02 -9.990000e+02 -9.990000e+02
# Result_Dividend FiscalYear                          2.020000e+03  2.020000e+03  2.021000e+03
# Result_Dividend QuarterlyDividendPerShare           2.200000e+01  2.200000e+01  2.200000e+01
# Result_Dividend AnnualDividendPerShare              4.400000e+01  4.400000e+01 -9.990000e+02
# Forecast_Dividend FiscalYear                       -9.990000e+02  2.021000e+03 -9.990000e+02
# Forecast_Dividend QuarterlyDividendPerShare        -9.990000e+02  2.200000e+01 -9.990000e+02
# Forecast_Dividend AnnualDividendPerShare           -9.990000e+02 -9.990000e+02 -9.990000e+02
# IssuedShareEquityQuote IssuedShare                  2.089814e+09  2.089814e+09  2.089814e+09
# Section/Products                                    1.000000e+00  1.000000e+00  1.000000e+00
# 33 Sector(Code)                                     5.250000e+03  5.250000e+03  5.250000e+03
# 17 Sector(Code)                                     1.000000e+01  1.000000e+01  1.000000e+01
# Previous_FinancialStatement NetSales                1.450055e+06  2.630531e+06 -9.990000e+02
# Previous_FinancialStatement OperatingIncome        -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement OrdinaryIncome          8.330470e+05  1.441472e+06 -9.990000e+02
# Previous_FinancialStatement NetIncome               1.255712e+06  1.883211e+06 -9.990000e+02
# Previous_FinancialStatement TotalAssets             3.356335e+07  3.564820e+07 -9.990000e+02
# Previous_FinancialStatement NetAssets               7.576780e+06  8.420605e+06 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromOperat... -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromFinanc... -9.990000e+02 -9.990000e+02 -9.990000e+02
# Previous_FinancialStatement CashFlowsFromInvest... -9.990000e+02 -9.990000e+02 -9.990000e+02
# operating_profit_margin                            -9.990000e+02 -9.990000e+02 -9.990000e+02
# ordinary_profit_margin                              5.744934e+01  5.744934e+01  5.479776e+01
# net_profit_margin                                   8.659754e+01  8.659754e+01  7.159053e+01
# total_asset_turnover                                1.913814e+01  1.913814e+01  3.123922e+01
# net_sales_growth_rate                               0.000000e+00 -4.487596e+01 -9.990000e+02
# ordinary_income_growth_rate                         0.000000e+00 -4.220859e+01 -9.990000e+02
# operationg_income_growth_rate                      -9.990000e+02 -9.990000e+02 -9.990000e+02
# total_assets_growth_rate                            0.000000e+00 -5.848400e+00 -9.990000e+02
# net_assets_growth_rate                              0.000000e+00 -1.002095e+01 -9.990000e+02
# eps                                                 6.008725e-04  6.008725e-04  9.011379e-04
# bps                                                 3.625576e-03  3.625576e-03  4.029356e-03
# roe                                                 1.657316e+01  1.657316e+01  2.236432e+01
# code                                                9.984000e+03  9.984000e+03  9.984000e+03
# datetime
# 2019-02-06    0.30407
# 2019-05-09    0.01429
# 2019-08-07    0.02409
# 2019-11-06    0.02106
# 2020-02-12    0.01495
# 2020-04-13    0.16952
# 2020-04-30    0.12670
# 2020-05-18    0.17356
# 2020-08-11    0.06131
# 2020-10-23    0.00607
# 2020-11-09    0.04645
# Name: label_high_20, dtype: float64

# %%
def get_codes(dfs):
    """
    Args:
        dfs (dict[pd.DataFrame]): loaded data
    Returns:
        array: list of stock codes
    """
    stock_list = dfs["stock_list"].copy()
    # 予測対象の銘柄コードを取得
    codes = stock_list[stock_list["prediction_target"] == True][
        "Local Code"
    ].values
    return codes

# %%
# 対象の目的変数を定義
labels = {
    "label_high_5",
    "label_high_10",
    "label_high_20",
    "label_low_5",
    "label_low_10",
    "label_low_20",
}
# 目的変数毎にデータを保存するための変数
train_X, val_X, test_X = {}, {}, {}
train_y, val_y, test_y = {}, {}, {}

# 予測対象銘柄を取得
codes = get_codes(dfs)

# 特徴量を作成
buff = []
for code in tqdm(codes):
    feat = get_features_for_predict(dfs, code)
    buff.append(feat)
feature = pd.concat(buff)

# 目的変数毎に処理
for label in tqdm(labels):
    # 特徴量と目的変数を取得
    _train_X, _train_y, _val_X, _val_y, _test_X, _test_y = get_features_and_label(dfs, codes, feature, label)
    # 目的変数をキーとして値を保存
    train_X[label] = _train_X
    val_X[label] = _val_X
    test_X[label] = _test_X
    train_y[label] = _train_y
    val_y[label] = _val_y
    test_y[label] = _test_y
# Out:
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3523), HTML(value='')))

# %%
# 目的変数を指定
label = "label_high_20"
# モデルの初期化
pred_model = RandomForestRegressor(random_state=0)
# モデルの学習
pred_model.fit(train_X[label], train_y[label])
# Out:
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
COLUMNS
# Out:
# ['Result_FinancialStatement FiscalYear',
#  'Result_FinancialStatement NetSales',
#  'Result_FinancialStatement OperatingIncome',
#  'Result_FinancialStatement OrdinaryIncome',
#  'Result_FinancialStatement NetIncome',
#  'Result_FinancialStatement TotalAssets',
#  'Result_FinancialStatement NetAssets',
#  'Result_FinancialStatement CashFlowsFromOperatingActivities',
#  'Result_FinancialStatement CashFlowsFromFinancingActivities',
#  'Result_FinancialStatement CashFlowsFromInvestingActivities',
#  'Forecast_FinancialStatement FiscalYear',
#  'Forecast_FinancialStatement NetSales',
#  'Forecast_FinancialStatement OperatingIncome',
#  'Forecast_FinancialStatement OrdinaryIncome',
#  'Forecast_FinancialStatement NetIncome',
#  'Result_Dividend FiscalYear',
#  'Result_Dividend QuarterlyDividendPerShare',
#  'Result_Dividend AnnualDividendPerShare',
#  'Forecast_Dividend FiscalYear',
#  'Forecast_Dividend QuarterlyDividendPerShare',
#  'Forecast_Dividend AnnualDividendPerShare',
#  'IssuedShareEquityQuote IssuedShare',
#  'Section/Products',
#  '33 Sector(Code)',
#  '17 Sector(Code)']

# %%
fin_data.T
# Out:
# datetime                                                          2016-02-10                2016-04-21  \
# Result_FinancialStatement FiscalYear                                    2016                      2016
# Result_FinancialStatement NetSales                               6.81021e+06               6.81021e+06
# Result_FinancialStatement OperatingIncome                             875322                    875322
# Result_FinancialStatement OrdinaryIncome                              918214                    918214
# Result_FinancialStatement NetIncome                                   428972                    428972
# Result_FinancialStatement TotalAssets                            2.14976e+07               2.14976e+07
# Result_FinancialStatement NetAssets                              3.85551e+06               3.85551e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                               NaN                       NaN
# Result_Dividend QuarterlyDividendPerShare                                NaN                       NaN
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2016                      2016
# Forecast_Dividend QuarterlyDividendPerShare                               20                        21
# Forecast_Dividend AnnualDividendPerShare                                  40                        41
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             6.81021e+06               9.15355e+06
# Previous_FinancialStatement OperatingIncome                           875322                    999488
# Previous_FinancialStatement OrdinaryIncome                            918214               1.00576e+06
# Previous_FinancialStatement NetIncome                                 428972                    474172
# Previous_FinancialStatement TotalAssets                          2.14976e+07               2.07072e+07
# Previous_FinancialStatement NetAssets                            3.85551e+06               3.50527e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                    940186
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                     43270
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN              -1.65168e+06
# operating_profit_margin                                              12.8531                   12.8531
# ordinary_profit_margin                                               13.4829                   13.4829
# net_profit_margin                                                    6.29896                   6.29896
# total_asset_turnover                                                 176.636                   176.636
# net_sales_growth_rate                                                      0                  -25.6004
# ordinary_income_growth_rate                                                0                  -8.70483
# operationg_income_growth_rate                                              0                   -12.423
# total_assets_growth_rate                                                   0                    3.8173
# net_assets_growth_rate                                                     0                    9.9917
# eps                                                              0.000205268               0.000205268
# bps                                                                0.0018449                 0.0018449
# roe                                                                  11.1262                   11.1262
#
# datetime                                                          2016-05-10                2016-07-28  \
# Result_FinancialStatement FiscalYear                                    2016                      2017
# Result_FinancialStatement NetSales                               9.15355e+06               2.12652e+06
# Result_FinancialStatement OperatingIncome                             999488                    319236
# Result_FinancialStatement OrdinaryIncome                         1.00576e+06                    356361
# Result_FinancialStatement NetIncome                                   474172                    254157
# Result_FinancialStatement TotalAssets                            2.07072e+07               2.06222e+07
# Result_FinancialStatement NetAssets                              3.50527e+06                 3.272e+06
# Result_FinancialStatement CashFlowsFromOperatin...                    940186                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                     43270                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...              -1.65168e+06                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2016                      2016
# Result_Dividend QuarterlyDividendPerShare                                 21                        21
# Result_Dividend AnnualDividendPerShare                                    41                        41
# Forecast_Dividend FiscalYear                                            2017                      2017
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             2.12652e+06               4.27183e+06
# Previous_FinancialStatement OperatingIncome                           319236                    653944
# Previous_FinancialStatement OrdinaryIncome                            356361                    665625
# Previous_FinancialStatement NetIncome                                 254157                    766249
# Previous_FinancialStatement TotalAssets                          2.06222e+07               2.28961e+07
# Previous_FinancialStatement NetAssets                              3.272e+06               3.12632e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                              10.9191                   15.0121
# ordinary_profit_margin                                               10.9877                   16.7579
# net_profit_margin                                                     5.1802                   11.9518
# total_asset_turnover                                                 261.137                   64.9916
# net_sales_growth_rate                                                330.447                    -50.22
# ordinary_income_growth_rate                                          182.232                  -46.4622
# operationg_income_growth_rate                                        213.087                   -51.183
# total_assets_growth_rate                                            0.411997                  -9.93117
# net_assets_growth_rate                                               7.12944                    4.6596
# eps                                                              0.000226897               0.000121617
# bps                                                               0.00167731                0.00156569
# roe                                                                  13.5274                   7.76764
#
# datetime                                                          2016-11-07                2017-02-08  \
# Result_FinancialStatement FiscalYear                                    2017                      2017
# Result_FinancialStatement NetSales                               4.27183e+06               6.58147e+06
# Result_FinancialStatement OperatingIncome                             653944                    949660
# Result_FinancialStatement OrdinaryIncome                              665625                    975257
# Result_FinancialStatement NetIncome                                   766249                    857431
# Result_FinancialStatement TotalAssets                            2.28961e+07                2.4867e+07
# Result_FinancialStatement NetAssets                              3.12632e+06               3.98171e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2017                      2017
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2017                      2017
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                  44                        44
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             6.58147e+06                 8.901e+06
# Previous_FinancialStatement OperatingIncome                           949660                 1.026e+06
# Previous_FinancialStatement OrdinaryIncome                            975257                    712526
# Previous_FinancialStatement NetIncome                                 857431               1.42631e+06
# Previous_FinancialStatement TotalAssets                           2.4867e+07               2.46342e+07
# Previous_FinancialStatement NetAssets                            3.98171e+06               4.46973e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN               1.50073e+06
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN               2.38075e+06
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN               -4.2136e+06
# operating_profit_margin                                              15.3083                   14.4293
# ordinary_profit_margin                                               15.5817                   14.8182
# net_profit_margin                                                    17.9372                    13.028
# total_asset_turnover                                                 136.641                   165.292
# net_sales_growth_rate                                                -35.093                  -26.0593
# ordinary_income_growth_rate                                         -31.7488                   36.8732
# operationg_income_growth_rate                                       -31.1391                  -7.44046
# total_assets_growth_rate                                              -7.926                  0.945133
# net_assets_growth_rate                                               -21.483                  -10.9183
# eps                                                              0.000366659               0.000410291
# bps                                                               0.00149598                0.00190529
# roe                                                                  24.5096                   21.5342
#
# datetime                                                          2017-05-10                2017-08-07  \
# Result_FinancialStatement FiscalYear                                    2017                      2018
# Result_FinancialStatement NetSales                                 8.901e+06               2.18606e+06
# Result_FinancialStatement OperatingIncome                          1.026e+06                    479273
# Result_FinancialStatement OrdinaryIncome                              712526                     77568
# Result_FinancialStatement NetIncome                              1.42631e+06                      5521
# Result_FinancialStatement TotalAssets                            2.46342e+07               2.48831e+07
# Result_FinancialStatement NetAssets                              4.46973e+06               4.65475e+06
# Result_FinancialStatement CashFlowsFromOperatin...               1.50073e+06                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...               2.38075e+06                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...               -4.2136e+06                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2017                      2017
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                    44                        44
# Forecast_Dividend FiscalYear                                            2018                      2018
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             2.18606e+06               4.41114e+06
# Previous_FinancialStatement OperatingIncome                           479273                    874839
# Previous_FinancialStatement OrdinaryIncome                             77568                    219021
# Previous_FinancialStatement NetIncome                                   5521                    102622
# Previous_FinancialStatement TotalAssets                          2.48831e+07               2.79735e+07
# Previous_FinancialStatement NetAssets                            4.65475e+06               5.46837e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                              11.5268                   21.9241
# ordinary_profit_margin                                               8.00501                    3.5483
# net_profit_margin                                                    16.0241                  0.252555
# total_asset_turnover                                                  199.14                   46.9641
# net_sales_growth_rate                                                307.171                  -50.4423
# ordinary_income_growth_rate                                          818.582                  -64.5842
# operationg_income_growth_rate                                        114.074                  -45.2159
# total_assets_growth_rate                                            -1.00035                  -11.0474
# net_assets_growth_rate                                              -3.97484                  -14.8787
# eps                                                              0.000682505               2.64186e-06
# bps                                                               0.00213882                0.00222735
# roe                                                                  31.9104                   0.11861
#
# datetime                                                          2017-11-06                2018-02-07  \
# Result_FinancialStatement FiscalYear                                    2018                      2018
# Result_FinancialStatement NetSales                               4.41114e+06               6.81127e+06
# Result_FinancialStatement OperatingIncome                             874839               1.14883e+06
# Result_FinancialStatement OrdinaryIncome                              219021                    563804
# Result_FinancialStatement NetIncome                                   102622               1.01494e+06
# Result_FinancialStatement TotalAssets                            2.79735e+07               2.94127e+07
# Result_FinancialStatement NetAssets                              5.46837e+06               6.56888e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2018                      2018
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2018                      2018
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                  44                        44
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             6.81127e+06               9.15876e+06
# Previous_FinancialStatement OperatingIncome                      1.14883e+06                1.3038e+06
# Previous_FinancialStatement OrdinaryIncome                            563804                    384630
# Previous_FinancialStatement NetIncome                            1.01494e+06               1.03898e+06
# Previous_FinancialStatement TotalAssets                          2.94127e+07               3.11805e+07
# Previous_FinancialStatement NetAssets                            6.56888e+06               6.27302e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN               1.08862e+06
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN               4.62642e+06
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN              -4.48482e+06
# operating_profit_margin                                              19.8325                   16.8666
# ordinary_profit_margin                                               4.96518                   8.27751
# net_profit_margin                                                    2.32643                   14.9009
# total_asset_turnover                                                 80.6663                    103.69
# net_sales_growth_rate                                               -35.2377                  -25.6311
# ordinary_income_growth_rate                                          -61.153                   46.5835
# operationg_income_growth_rate                                       -23.8495                  -11.8862
# total_assets_growth_rate                                            -4.89324                  -5.66941
# net_assets_growth_rate                                              -16.7533                   4.71631
# eps                                                              4.91058e-05               0.000485662
# bps                                                               0.00261668                0.00314328
# roe                                                                  1.87665                   15.4508
#
# datetime                                                          2018-05-09                2018-08-06  \
# Result_FinancialStatement FiscalYear                                    2018                      2019
# Result_FinancialStatement NetSales                               9.15876e+06               2.27278e+06
# Result_FinancialStatement OperatingIncome                         1.3038e+06                    714993
# Result_FinancialStatement OrdinaryIncome                              384630                    572304
# Result_FinancialStatement NetIncome                              1.03898e+06                    313687
# Result_FinancialStatement TotalAssets                            3.11805e+07               3.22684e+07
# Result_FinancialStatement NetAssets                              6.27302e+06               6.82117e+06
# Result_FinancialStatement CashFlowsFromOperatin...               1.08862e+06                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...               4.62642e+06                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...              -4.48482e+06                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2018                      2018
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                    44                        44
# Forecast_Dividend FiscalYear                                             NaN                      2019
# Forecast_Dividend QuarterlyDividendPerShare                              NaN                        22
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             2.27278e+06               4.65385e+06
# Previous_FinancialStatement OperatingIncome                           714993               1.42072e+06
# Previous_FinancialStatement OrdinaryIncome                            572304               1.40209e+06
# Previous_FinancialStatement NetIncome                                 313687                    840103
# Previous_FinancialStatement TotalAssets                          3.22684e+07               3.38076e+07
# Previous_FinancialStatement NetAssets                            6.82117e+06               7.34314e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                              14.2356                   31.4589
# ordinary_profit_margin                                               4.19958                   25.1808
# net_profit_margin                                                    11.3441                   13.8019
# total_asset_turnover                                                 146.002                   33.3195
# net_sales_growth_rate                                                302.976                  -51.1634
# ordinary_income_growth_rate                                         -32.7927                   -59.182
# operationg_income_growth_rate                                        82.3516                  -49.6738
# total_assets_growth_rate                                            -3.37141                   -4.5528
# net_assets_growth_rate                                              -8.03604                  -7.10826
# eps                                                              0.000497162               0.000150103
# bps                                                               0.00300171                0.00326401
# roe                                                                  16.5626                   4.59872
#
# datetime                                                          2018-11-05                2019-02-06  \
# Result_FinancialStatement FiscalYear                                    2019                      2019
# Result_FinancialStatement NetSales                               4.65385e+06               7.16845e+06
# Result_FinancialStatement OperatingIncome                        1.42072e+06               1.85901e+06
# Result_FinancialStatement OrdinaryIncome                         1.40209e+06               1.80983e+06
# Result_FinancialStatement NetIncome                                   840103                1.5384e+06
# Result_FinancialStatement TotalAssets                            3.38076e+07               3.64595e+07
# Result_FinancialStatement NetAssets                              7.34314e+06               9.28639e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2019                      2019
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2019                      2019
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                  44                        44
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             7.16845e+06               9.60224e+06
# Previous_FinancialStatement OperatingIncome                      1.85901e+06               2.35393e+06
# Previous_FinancialStatement OrdinaryIncome                       1.80983e+06                1.6913e+06
# Previous_FinancialStatement NetIncome                             1.5384e+06                1.4112e+06
# Previous_FinancialStatement TotalAssets                          3.64595e+07               3.60965e+07
# Previous_FinancialStatement NetAssets                            9.28639e+06                9.0092e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN               1.17186e+06
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN               2.20229e+06
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN              -2.90802e+06
# operating_profit_margin                                              30.5277                   25.9332
# ordinary_profit_margin                                               30.1275                   25.2472
# net_profit_margin                                                    18.0518                   21.4606
# total_asset_turnover                                                 63.3768                   77.1931
# net_sales_growth_rate                                               -35.0787                   -25.346
# ordinary_income_growth_rate                                         -22.5294                   7.00833
# operationg_income_growth_rate                                       -23.5766                  -21.0254
# total_assets_growth_rate                                            -7.27362                   1.00564
# net_assets_growth_rate                                              -20.9257                   3.07669
# eps                                                              0.000401999                0.00073614
# bps                                                               0.00351378                0.00444364
# roe                                                                  11.4406                   16.5661
#
# datetime                                                          2019-05-09                2019-08-07  \
# Result_FinancialStatement FiscalYear                                    2019                      2020
# Result_FinancialStatement NetSales                               9.60224e+06                2.3364e+06
# Result_FinancialStatement OperatingIncome                        2.35393e+06                    688816
# Result_FinancialStatement OrdinaryIncome                          1.6913e+06               1.68234e+06
# Result_FinancialStatement NetIncome                               1.4112e+06               1.12172e+06
# Result_FinancialStatement TotalAssets                            3.60965e+07                3.6587e+07
# Result_FinancialStatement NetAssets                               9.0092e+06               9.44533e+06
# Result_FinancialStatement CashFlowsFromOperatin...               1.17186e+06                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...               2.20229e+06                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...              -2.90802e+06                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2019                      2019
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                    44                        44
# Forecast_Dividend FiscalYear                                            2020                      2020
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                              2.3364e+06               4.65172e+06
# Previous_FinancialStatement OperatingIncome                           688816                    -15552
# Previous_FinancialStatement OrdinaryIncome                       1.68234e+06                1.1169e+06
# Previous_FinancialStatement NetIncome                            1.12172e+06                    421552
# Previous_FinancialStatement TotalAssets                           3.6587e+07               3.68487e+07
# Previous_FinancialStatement NetAssets                            9.44533e+06               8.62363e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                              24.5144                    29.482
# ordinary_profit_margin                                               17.6136                   72.0059
# net_profit_margin                                                    14.6966                   48.0106
# total_asset_turnover                                                 106.583                    24.736
# net_sales_growth_rate                                                310.985                  -49.7735
# ordinary_income_growth_rate                                         0.532471                   50.6266
# operationg_income_growth_rate                                        241.736                  -4529.12
# total_assets_growth_rate                                             -1.3406                  -0.71031
# net_assets_growth_rate                                              -4.61739                   9.52854
# eps                                                              0.000675275               0.000536755
# bps                                                               0.00431101                 0.0045197
# roe                                                                   15.664                   11.8759
#
# datetime                                                          2019-11-06                2020-02-12  \
# Result_FinancialStatement FiscalYear                                    2020                      2020
# Result_FinancialStatement NetSales                               4.65172e+06                7.0898e+06
# Result_FinancialStatement OperatingIncome                             -15552                    -12964
# Result_FinancialStatement OrdinaryIncome                          1.1169e+06               1.34538e+06
# Result_FinancialStatement NetIncome                                   421552                    476587
# Result_FinancialStatement TotalAssets                            3.68487e+07               3.94064e+07
# Result_FinancialStatement NetAssets                              8.62363e+06               9.19142e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2020                      2020
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2020                      2020
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                  44                        44
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                              7.0898e+06                7.0898e+06
# Previous_FinancialStatement OperatingIncome                           -12964                    -12964
# Previous_FinancialStatement OrdinaryIncome                       1.34538e+06               1.34538e+06
# Previous_FinancialStatement NetIncome                                 476587                    476587
# Previous_FinancialStatement TotalAssets                          3.94064e+07               3.94064e+07
# Previous_FinancialStatement NetAssets                            9.19142e+06               9.19142e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                            -0.334328                 -0.182854
# ordinary_profit_margin                                               24.0104                   18.9762
# net_profit_margin                                                    9.06227                   6.72215
# total_asset_turnover                                                 53.9416                    77.135
# net_sales_growth_rate                                               -34.3885                         0
# ordinary_income_growth_rate                                         -16.9827                         0
# operationg_income_growth_rate                                         19.963                        -0
# total_assets_growth_rate                                            -6.49066                         0
# net_assets_growth_rate                                              -6.17742                         0
# eps                                                              0.000201717               0.000228052
# bps                                                                0.0041265                 0.0043982
# roe                                                                  4.88834                   5.18513
#
# datetime                                                          2020-04-13                2020-04-30  \
# Result_FinancialStatement FiscalYear                                    2020                      2020
# Result_FinancialStatement NetSales                                7.0898e+06                7.0898e+06
# Result_FinancialStatement OperatingIncome                             -12964                    -12964
# Result_FinancialStatement OrdinaryIncome                         1.34538e+06               1.34538e+06
# Result_FinancialStatement NetIncome                                   476587                    476587
# Result_FinancialStatement TotalAssets                            3.94064e+07               3.94064e+07
# Result_FinancialStatement NetAssets                              9.19142e+06               9.19142e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                  2020                      2020
# Forecast_FinancialStatement NetSales                                6.15e+06                  6.15e+06
# Forecast_FinancialStatement OperatingIncome                        -1.35e+06                 -1.35e+06
# Forecast_FinancialStatement OrdinaryIncome                            250000                     20000
# Forecast_FinancialStatement NetIncome                                -750000                   -900000
# Result_Dividend FiscalYear                                              2020                      2020
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                   NaN                       NaN
# Forecast_Dividend FiscalYear                                            2020                      2020
# Forecast_Dividend QuarterlyDividendPerShare                               22                        22
# Forecast_Dividend AnnualDividendPerShare                                  44                        44
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                              7.0898e+06               6.18509e+06
# Previous_FinancialStatement OperatingIncome                           -12964              -1.36463e+06
# Previous_FinancialStatement OrdinaryIncome                       1.34538e+06                     35492
# Previous_FinancialStatement NetIncome                                 476587                   -961576
# Previous_FinancialStatement TotalAssets                          3.94064e+07               3.72573e+07
# Previous_FinancialStatement NetAssets                            9.19142e+06               7.37292e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN               1.11788e+06
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN               2.92086e+06
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN              -4.28692e+06
# operating_profit_margin                                            -0.182854                 -0.182854
# ordinary_profit_margin                                               18.9762                   18.9762
# net_profit_margin                                                    6.72215                   6.72215
# total_asset_turnover                                                  77.135                    77.135
# net_sales_growth_rate                                                      0                   14.6273
# ordinary_income_growth_rate                                                0                   3690.65
# operationg_income_growth_rate                                             -0                    -99.05
# total_assets_growth_rate                                                   0                   5.76839
# net_assets_growth_rate                                                     0                   24.6646
# eps                                                              0.000228052               0.000228052
# bps                                                                0.0043982                 0.0043982
# roe                                                                  5.18513                   5.18513
#
# datetime                                                          2020-05-18                2020-08-11  \
# Result_FinancialStatement FiscalYear                                    2020                      2021
# Result_FinancialStatement NetSales                               6.18509e+06               1.45006e+06
# Result_FinancialStatement OperatingIncome                       -1.36463e+06                       NaN
# Result_FinancialStatement OrdinaryIncome                               35492                    833047
# Result_FinancialStatement NetIncome                                  -961576               1.25571e+06
# Result_FinancialStatement TotalAssets                            3.72573e+07               3.35633e+07
# Result_FinancialStatement NetAssets                              7.37292e+06               7.57678e+06
# Result_FinancialStatement CashFlowsFromOperatin...               1.11788e+06                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...               2.92086e+06                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...              -4.28692e+06                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2020                      2020
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                    44                        44
# Forecast_Dividend FiscalYear                                             NaN                       NaN
# Forecast_Dividend QuarterlyDividendPerShare                              NaN                       NaN
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             1.45006e+06               1.45006e+06
# Previous_FinancialStatement OperatingIncome                              NaN                       NaN
# Previous_FinancialStatement OrdinaryIncome                            833047                    833047
# Previous_FinancialStatement NetIncome                            1.25571e+06               1.25571e+06
# Previous_FinancialStatement TotalAssets                          3.35633e+07               3.35633e+07
# Previous_FinancialStatement NetAssets                            7.57678e+06               7.57678e+06
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                             -22.0633                       NaN
# ordinary_profit_margin                                              0.573831                   57.4493
# net_profit_margin                                                   -15.5467                   86.5975
# total_asset_turnover                                                 83.8894                   19.1381
# net_sales_growth_rate                                                326.542                         0
# ordinary_income_growth_rate                                         -95.7395                         0
# operationg_income_growth_rate                                            NaN                       NaN
# total_assets_growth_rate                                             11.0059                         0
# net_assets_growth_rate                                              -2.69063                         0
# eps                                                             -0.000460125               0.000600873
# bps                                                               0.00352802                0.00362558
# roe                                                                  -13.042                   16.5732
#
# datetime                                                          2020-10-23                2020-11-09
# Result_FinancialStatement FiscalYear                                    2021                      2021
# Result_FinancialStatement NetSales                               1.45006e+06               2.63053e+06
# Result_FinancialStatement OperatingIncome                                NaN                       NaN
# Result_FinancialStatement OrdinaryIncome                              833047               1.44147e+06
# Result_FinancialStatement NetIncome                              1.25571e+06               1.88321e+06
# Result_FinancialStatement TotalAssets                            3.35633e+07               3.56482e+07
# Result_FinancialStatement NetAssets                              7.57678e+06               8.42060e+06
# Result_FinancialStatement CashFlowsFromOperatin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromFinancin...                       NaN                       NaN
# Result_FinancialStatement CashFlowsFromInvestin...                       NaN                       NaN
# Forecast_FinancialStatement FiscalYear                                   NaN                       NaN
# Forecast_FinancialStatement NetSales                                     NaN                       NaN
# Forecast_FinancialStatement OperatingIncome                              NaN                       NaN
# Forecast_FinancialStatement OrdinaryIncome                               NaN                       NaN
# Forecast_FinancialStatement NetIncome                                    NaN                       NaN
# Result_Dividend FiscalYear                                              2020                      2021
# Result_Dividend QuarterlyDividendPerShare                                 22                        22
# Result_Dividend AnnualDividendPerShare                                    44                       NaN
# Forecast_Dividend FiscalYear                                            2021                       NaN
# Forecast_Dividend QuarterlyDividendPerShare                               22                       NaN
# Forecast_Dividend AnnualDividendPerShare                                 NaN                       NaN
# IssuedShareEquityQuote IssuedShare                               2.08981e+09               2.08981e+09
# Section/Products                                    First Section (Domestic)  First Section (Domestic)
# 33 Sector(Code)                                                         5250                      5250
# 17 Sector(Code)                                                           10                        10
# Previous_FinancialStatement NetSales                             2.63053e+06                       NaN
# Previous_FinancialStatement OperatingIncome                              NaN                       NaN
# Previous_FinancialStatement OrdinaryIncome                       1.44147e+06                       NaN
# Previous_FinancialStatement NetIncome                            1.88321e+06                       NaN
# Previous_FinancialStatement TotalAssets                          3.56482e+07                       NaN
# Previous_FinancialStatement NetAssets                            8.42060e+06                       NaN
# Previous_FinancialStatement CashFlowsFromOperat...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromFinanc...                       NaN                       NaN
# Previous_FinancialStatement CashFlowsFromInvest...                       NaN                       NaN
# operating_profit_margin                                                  NaN                       NaN
# ordinary_profit_margin                                               57.4493                   54.7978
# net_profit_margin                                                    86.5975                   71.5905
# total_asset_turnover                                                 19.1381                   31.2392
# net_sales_growth_rate                                                -44.876                       NaN
# ordinary_income_growth_rate                                         -42.2086                       NaN
# operationg_income_growth_rate                                            NaN                       NaN
# total_assets_growth_rate                                             -5.8484                       NaN
# net_assets_growth_rate                                               -10.021                       NaN
# eps                                                              0.000600873               0.000901138
# bps                                                               0.00362558                0.00402936
# roe                                                                  16.5732                   22.3643

# %%
technical_cols
# Out:
# ['return_1month',
#  'return_2month',
#  'return_3month',
#  'volatility_1month',
#  'volatility_2month',
#  'volatility_3month',
#  'MA_gap_1month',
#  'MA_gap_2month',
#  'MA_gap_3month',
#  'EWMA',
#  'ema_10',
#  'ema_12',
#  'ema_26',
#  'macd',
#  'signal',
#  'pbr',
#  'per',
#  'Section/Products',
#  '33 Sector(Code)',
#  '17 Sector(Code)']

# %%
# モデルを定義
models = {
    "rf": RandomForestRegressor,
}

# モデルを選択
model = "rf"

# 目的変数を指定
label = "label_high_20"

# 学習用データセット定義
# ファンダメンタル情報
#fundamental_cols = dfs["stock_fin"].select_dtypes("float64").columns
fundamental_cols = fin_data.select_dtypes("float64").columns
fundamental_cols = fundamental_cols[fundamental_cols != "Result_Dividend DividendPayableDate"]
fundamental_cols = fundamental_cols[fundamental_cols != "Local Code"]
# 価格変化率
returns_cols = [x for x in train_X[label].columns if "return" in x]
# テクニカル
technical_cols = [x for x in train_X[label].columns if (x not in fundamental_cols) and (x != "code")]

columns = {
    "fundamental_only": fundamental_cols,
    "return_only": returns_cols,
    "technical_only": technical_cols,
    "fundamental+technical": list(fundamental_cols) + list(technical_cols),
}
# 学習用データセットを指定
col = "fundamental_only"

# 学習
pred_model = models[model](random_state=0)
pred_model.fit(train_X[label][columns[col]].values, train_y[label])

# 予測
result = {}
result[label] = pd.DataFrame(
    pred_model.predict(val_X[label][columns[col]]), columns=["predict"]
)

# 予測結果に日付と銘柄コードを追加
result[label]["datetime"] = val_X[label][columns[col]].index
result[label]["code"] = val_X[label]["code"].values

# 予測の符号を取得
result[label]["predict_dir"] = np.sign(result[label]["predict"])

# 実際の値を追加
result[label]["actual"] = val_y[label].values
# Out:
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.

# %% [markdown]
# # Submit Model

# %%
model_path = os.path.join(os.path.dirname("__file__"), "../model")
# tag::save_model[]
# モデル保存先ディレクトリを作成
os.makedirs(model_path, exist_ok=True)
with open(os.path.join(model_path, f"my_model_{label}.pkl"), "wb") as f:
    # モデルをpickle形式で保存
    pickle.dump(pred_model, f)

# %%
sns.jointplot(data=result[label], x="predict", y="actual")

# %%
pred_model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# 学習済みモデルを指定
rf = pred_model

# 重要度順を取得
sorted_idx = rf.feature_importances_.argsort()
# プロット
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(fundamental_cols[sorted_idx], rf.feature_importances_[sorted_idx])
ax.set_xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
# モデルを定義します
sample_model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(train_X["label_high_20"], label=train_y["label_high_20"]), 100)

# %%
shap.initjs()
explainer = shap.TreeExplainer(model=sample_model, feature_perturbation='tree_path_dependent', model_output='margin')
# SHAP値
shap_values = explainer.shap_values(X=train_X["label_high_20"])
# プロット
shap.summary_plot(shap_values, train_X["label_high_20"], plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# model_output = "margin" has been renamed to model_output = "raw"

# %%
shap.summary_plot(shap_values, train_X["label_high_20"])

# %%
# モデルを定義
models = {
    "rf": RandomForestRegressor,
    "extraTree": ExtraTreesRegressor,
    "gbr": GradientBoostingRegressor,
}

# 学習用データセット定義
columns = {
    "fundamental_only": fundamental_cols,
    "return_only": returns_cols,
    "technical_only": technical_cols,
    "fundamental+technical": list(fundamental_cols) + list(technical_cols),
}

# 結果保存用
all_results = dict()
# モデル毎に処理
for model in tqdm(models.keys()):
    all_results[model] = dict()
    # データセット毎に処理
    for col in columns.keys():
        result = dict()
        # 目的変数毎に処理
        for label in tqdm(labels):
            if len(test_X[label][columns[col]]) > 0:
                # モデル取得
                pred_model = models[model](random_state=0)
                # 学習
                pred_model.fit(train_X[label][columns[col]].values, train_y[label])
                # 結果データ作成
                result[label] = test_X[label][["code"]].copy()
                result[label]["datetime"] = test_X[label][columns[col]].index
                # 予測
                result[label]["predict"] = pred_model.predict(test_X[label][columns[col]])
                result[label]["predict_dir"] = np.sign(result[label]["predict"])
                # 実際の結果
                result[label]["actual"] = test_y[label].values
                result[label]["actual_dir"] = np.sign(result[label]["actual"])
                result[label].dropna(inplace=True)

        all_results[model][col] = result
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
results = []
for model in all_results.keys():
    for col in all_results[model]:
        tmp = pd.concat(all_results[model][col])
        tmp["model"] = model
        tmp["feature"] = col
        results.append(tmp)
results = pd.concat(results)
results["label"] = [x[0] for x in results.index]
results.head(5)
# Out:
#                           code   datetime   predict  predict_dir   actual  actual_dir model           feature  \
#               datetime
# label_high_10 2019-02-08  1301 2019-02-08  0.088536          1.0  0.07143         1.0    rf  fundamental_only
#               2019-05-13  1301 2019-05-13  0.059628          1.0  0.04379         1.0    rf  fundamental_only
#               2019-08-02  1301 2019-08-02  0.042958          1.0  0.00498         1.0    rf  fundamental_only
#               2019-11-05  1301 2019-11-05  0.071258          1.0  0.00841         1.0    rf  fundamental_only
#               2020-02-07  1301 2020-02-07  0.110373          1.0  0.01212         1.0    rf  fundamental_only
#
#                                   label
#               datetime
# label_high_10 2019-02-08  label_high_10
#               2019-05-13  label_high_10
#               2019-08-02  label_high_10
#               2019-11-05  label_high_10
#               2020-02-07  label_high_10

# %%
# 結果保存用変数
all_metrics = []

# データセット毎に処理
for feature in columns:
    matrix = dict()
    # モデル毎に処理
    for model in models:
        # 目的変数毎に処理
        for label in labels:
            # 処理対象データに絞り込み
            tmp_df = results[(results["model"] == model) & (results["label"] == label) & (results["feature"] == feature)]
            # RMSE
            rmse = np.sqrt(mean_squared_error(tmp_df["predict"], tmp_df["actual"]))
            # 精度
            accuracy = accuracy_score(tmp_df["predict_dir"], tmp_df["actual_dir"])
            # 相関係数
            corr = np.corrcoef(tmp_df["actual"], tmp_df["predict"])[0, 1]
            # 順位相関
            spearman_corr = spearmanr(tmp_df["actual"], tmp_df["predict"])[0]
            # 結果を保存
            matrix[label] = [rmse, accuracy, spearman_corr,corr, corr**2, feature, model, tmp_df.shape[0]]
        res = pd.DataFrame.from_dict(matrix).T
        res.columns = ["RMSE","accuracy","spearman_corr","corr","R^2 score","feature", "model", "# of samples"]
        all_metrics.append(res)
all_metrics = pd.concat(all_metrics)
all_metrics.reset_index()
# Out:
#             index       RMSE  accuracy spearman_corr       corr    R^2 score                feature      model  \
# 0   label_high_20   0.233039  0.828664      0.128185   0.106541    0.0113509       fundamental_only         rf
# 1   label_high_10   0.210684  0.780073     0.0921569  0.0514768   0.00264986       fundamental_only         rf
# 2    label_low_20   0.107852  0.855636     0.0368938  0.0359023   0.00128898       fundamental_only         rf
# 3    label_low_10  0.0833718  0.828134     0.0431829  0.0309461  0.000957659       fundamental_only         rf
# 4    label_high_5    0.23053    0.7237     0.0853635  0.0166752  0.000278063       fundamental_only         rf
# 5     label_low_5  0.0717196   0.79192     0.0621861  0.0554279   0.00307226       fundamental_only         rf
# 6   label_high_20   0.209899  0.824081      0.104088   0.112833    0.0127313       fundamental_only  extraTree
# 7   label_high_10   0.190942  0.777292      0.079988  0.0575084   0.00330721       fundamental_only  extraTree
# 8    label_low_20    0.11031  0.840597     0.0711386   0.069259   0.00479681       fundamental_only  extraTree
# 9    label_low_10  0.0840982  0.793303     0.0711324  0.0655109   0.00429168       fundamental_only  extraTree
# 10   label_high_5   0.135998  0.715211     0.0683503  0.0571123   0.00326182       fundamental_only  extraTree
# 11    label_low_5  0.0721229  0.767765     0.0731409  0.0683073   0.00466589       fundamental_only  extraTree
# 12  label_high_20   0.264674  0.832231       0.15031  0.0586371    0.0034383       fundamental_only        gbr
# 13  label_high_10   0.199703  0.793333      0.132924  0.0376248   0.00141563       fundamental_only        gbr
# 14   label_low_20   0.104623  0.867692     0.0923764  0.0960815   0.00923165       fundamental_only        gbr
# 15   label_low_10  0.0763277  0.816157      0.139693   0.123797    0.0153257       fundamental_only        gbr
# 16   label_high_5   0.112399  0.748313        0.1212  0.0543801    0.0029572       fundamental_only        gbr
# 17    label_low_5  0.0660234  0.801722       0.14319   0.126059    0.0158908       fundamental_only        gbr
# 18  label_high_20   0.185752  0.823282      0.110237   0.113578    0.0128999            return_only         rf
# 19  label_high_10   0.129829  0.776253      0.111806   0.131957    0.0174127            return_only         rf
# 20   label_low_20   0.110458   0.85256     0.0481166  0.0435957   0.00190059            return_only         rf
# 21   label_low_10   0.081337  0.816829      0.071025  0.0829074   0.00687363            return_only         rf
# 22   label_high_5   0.106834  0.718051     0.0699687  0.0975259    0.0095113            return_only         rf
# 23    label_low_5  0.0711497  0.772804     0.0889798  0.0969606   0.00940136            return_only         rf
# 24  label_high_20   0.188424  0.822267      0.105818    0.10616      0.01127            return_only  extraTree
# 25  label_high_10   0.133704  0.774206      0.107821   0.119323     0.014238            return_only  extraTree
# 26   label_low_20   0.110738  0.848039     0.0538791  0.0497924   0.00247928            return_only  extraTree
# 27   label_low_10   0.081953  0.811207     0.0771557  0.0846993   0.00717397            return_only  extraTree
# 28   label_high_5    0.10956  0.713989      0.060361  0.0835352   0.00697813            return_only  extraTree
# 29    label_low_5  0.0723567  0.765933     0.0770383  0.0814365    0.0066319            return_only  extraTree
# 30  label_high_20   0.164271  0.832293      0.221589   0.203304    0.0413327            return_only        gbr
# 31  label_high_10    0.11749  0.793486      0.195371   0.196417    0.0385795            return_only        gbr
# 32   label_low_20   0.105579  0.867938     0.0940464  0.0827456   0.00684684            return_only        gbr
# 33   label_low_10  0.0758897  0.838553      0.137795   0.132462    0.0175463            return_only        gbr
# 34   label_high_5  0.0972356  0.748527      0.155054   0.173483    0.0300965            return_only        gbr
# 35    label_low_5  0.0658795   0.80612      0.160278   0.152328    0.0232037            return_only        gbr
# 36  label_high_20   0.180997  0.830201      0.189548   0.180697    0.0326515         technical_only         rf
# 37  label_high_10   0.126895  0.787497      0.158043   0.183123    0.0335339         technical_only         rf
# 38   label_low_20   0.107884  0.856343      0.113478  0.0999952   0.00999905         technical_only         rf
# 39   label_low_10  0.0783546  0.820862      0.146008   0.153478    0.0235556         technical_only         rf
# 40   label_high_5   0.102873   0.73396      0.129495   0.142587    0.0203312         technical_only         rf
# 41    label_low_5  0.0687051  0.779858      0.166907   0.166453    0.0277066         technical_only         rf
# 42  label_high_20   0.175196  0.830263       0.16808   0.195655    0.0382809         technical_only  extraTree
# 43  label_high_10   0.125203  0.786611      0.148071   0.175063    0.0306471         technical_only  extraTree
# 44   label_low_20   0.107122  0.857881      0.117749    0.12106    0.0146555         technical_only  extraTree
# 45   label_low_10  0.0780395  0.822726      0.143836   0.159134    0.0253236         technical_only  extraTree
# 46   label_high_5   0.103165  0.734418      0.112423   0.126248    0.0159385         technical_only  extraTree
# 47    label_low_5  0.0688345  0.779674      0.151132   0.157454    0.0247919         technical_only  extraTree
# 48  label_high_20   0.163004  0.832293      0.263101   0.246976    0.0609971         technical_only        gbr
# 49  label_high_10   0.117578  0.793486      0.228686   0.224926    0.0505918         technical_only        gbr
# 50   label_low_20   0.104608  0.867876      0.151678   0.140231    0.0196648         technical_only        gbr
# 51   label_low_10  0.0746972    0.8384      0.201328   0.203422    0.0413806         technical_only        gbr
# 52   label_high_5  0.0976822  0.748069      0.202286   0.179276      0.03214         technical_only        gbr
# 53    label_low_5  0.0645566  0.805845      0.235376    0.23738    0.0563493         technical_only        gbr
# 54  label_high_20   0.224975   0.83097      0.207211   0.152324    0.0232025  fundamental+technical         rf
# 55  label_high_10   0.178583   0.78435      0.163903   0.100324    0.0100648  fundamental+technical         rf
# 56   label_low_20   0.106266  0.856343      0.120203   0.117824    0.0138824  fundamental+technical         rf
# 57   label_low_10  0.0785998  0.820007      0.137147   0.146557    0.0214788  fundamental+technical         rf
# 58   label_high_5   0.142552  0.736403      0.134326  0.0637298   0.00406149  fundamental+technical         rf
# 59    label_low_5  0.0693835  0.773506      0.162774   0.161567    0.0261038  fundamental+technical         rf
# 60  label_high_20   0.190722  0.830171      0.194684    0.17991    0.0323675  fundamental+technical  extraTree
# 61  label_high_10   0.134034  0.789178      0.164048   0.166024     0.027564  fundamental+technical  extraTree
# 62   label_low_20   0.105436  0.857881      0.128962   0.129318    0.0167233  fundamental+technical  extraTree
# 63   label_low_10  0.0780108  0.821046       0.14949   0.158419    0.0250965  fundamental+technical  extraTree
# 64   label_high_5    0.11121  0.733991      0.126192   0.118981    0.0141564  fundamental+technical  extraTree
# 65    label_low_5  0.0685197  0.777567      0.148025   0.159219    0.0253507  fundamental+technical  extraTree
# 66  label_high_20   0.191446  0.832293      0.234094   0.150519     0.022656  fundamental+technical        gbr
# 67  label_high_10   0.163103  0.793455      0.211969  0.0923604   0.00853044  fundamental+technical        gbr
# 68   label_low_20   0.105937  0.834323      0.153096   0.154789    0.0239596  fundamental+technical        gbr
# 69   label_low_10  0.0770123  0.826209      0.192941   0.167904    0.0281918  fundamental+technical        gbr
# 70   label_high_5   0.166038  0.748007      0.183275  0.0435277   0.00189466  fundamental+technical        gbr
# 71    label_low_5  0.0668618  0.760833      0.222086    0.20474    0.0419186  fundamental+technical        gbr
#
#    # of samples
# 0         32515
# 1         32729
# 2         32515
# 3         32729
# 4         32747
# 5         32747
# 6         32515
# 7         32729
# 8         32515
# 9         32729
# 10        32747
# 11        32747
# 12        32515
# 13        32729
# 14        32515
# 15        32729
# 16        32747
# 17        32747
# 18        32515
# 19        32729
# 20        32515
# 21        32729
# 22        32747
# 23        32747
# 24        32515
# 25        32729
# 26        32515
# 27        32729
# 28        32747
# 29        32747
# 30        32515
# 31        32729
# 32        32515
# 33        32729
# 34        32747
# 35        32747
# 36        32515
# 37        32729
# 38        32515
# 39        32729
# 40        32747
# 41        32747
# 42        32515
# 43        32729
# 44        32515
# 45        32729
# 46        32747
# 47        32747
# 48        32515
# 49        32729
# 50        32515
# 51        32729
# 52        32747
# 53        32747
# 54        32515
# 55        32729
# 56        32515
# 57        32729
# 58        32747
# 59        32747
# 60        32515
# 61        32729
# 62        32515
# 63        32729
# 64        32747
# 65        32747
# 66        32515
# 67        32729
# 68        32515
# 69        32729
# 70        32747
# 71        32747
